# %%
import os
import sys
import csv
import re
import string
import collections
from konlpy.tag import Komoran

class Preprocess:
    def __init__(self):
        self.komoran = Komoran()
        with open('datasets/stopwords.txt', 'r', encoding='utf-8') as f:
            self.stopwords = set(f.read().split(','))

    def preprocess(self, text):
        text = text.strip()
        text = re.compile('<.*?>').sub('', text)
        text = re.compile('[%s]' % re.escape(string.punctuation)).sub(' ', text)
        text = re.sub('\s+', ' ', text)
        text = re.sub(r'[^\w\s]', ' ', str(text).strip())
        text = re.sub(r'\d', ' ', text)
        text = re.sub(r'\s+', ' ', text)
        return text

    def is_korean(self, text):
        korean_pattern = re.compile('[^ㄱ-ㅎ|ㅏ-ㅣ|가-힣]+')
        if korean_pattern.search(text):
            return False
        return True

    def final(self, text):
        n = []
        word = self.komoran.nouns(text)
        p = self.komoran.pos(text)
        for pos in p:
            if pos[1] in ['SL'] and self.is_korean(pos[0]):
                word.append(pos[0])
        for w in word:
            if len(w) > 1 and w not in self.stopwords:
                n.append(w)
        return " ".join(n)

    def finalpreprocess(self, documents):
        for doc in documents:
            doc['article'] = self.final(self.preprocess(doc['article']))
        return documents

def load_documents(file_path):
    documents = []
    with open(file_path, mode='r', encoding='cp949') as file:
        reader = csv.DictReader(file)
        for row in reader:
            title = row['title']
            article = row['article']
            documents.append({'title': title, 'article': article})
    return documents

def filter_documents(documents, exclude_words):
    filtered_documents = []
    for doc in documents:
        article_words = doc['article'].split()
        filtered_words = [word for word in article_words if word not in exclude_words]
        filtered_article = ' '.join(filtered_words)
        if filtered_article.endswith('서울'):
            filtered_article = filtered_article.rsplit(' ', 1)[0]
        doc['article'] = filtered_article
        filtered_documents.append(doc)
    return filtered_documents
    
## tests ########################################################################################

def textrank(document, window_size=2, rsp=0.15):
    '''
    This function accepts a string representation
    of a document and three hyperperameters as input.
    It returns Pandas matrix (that can be treated
    as a dictionary) that maps words in the
    document to their associated TextRank significance
    scores. Note that only words that are classified
    as having relevant POS tags are present in the
    map.
    '''
        
    # Build a weighted graph where nodes are words and
    # edge weights are the number of times words cooccur
    # within a window of predetermined size. In doing so
    # we double count each coocurrence, but that will not
    # alter relative weights which ultimately determine
    # TextRank scores.
    words = document
    edge_weights = collections.defaultdict(lambda: collections.Counter())
    for index, word in enumerate(words):
        for other_index in range(index - window_size, index + window_size + 1):
            if other_index >= 0 and other_index < len(words) and other_index != index:
                other_word = words[other_index]
                edge_weights[word][other_word] += 1.0

    # Apply PageRank to the weighted graph:
    word_probabilities = pagerank.power_iteration(edge_weights, rsp=rsp)
    word_probabilities.sort_values(ascending=False)

    return word_probabilities
    
def apply_text_tank(documents, title="a document"):
    print()
    print("Applying TextRank to \"%s\" ..." % title)
    
    for doc in documents:
        document = doc['article']
        keyword_scores = textrank(document)
        
        print()
        header = "Keyword Significance Scores for \"%s\":" % doc['title']
        print(header)
        print("-" * len(header))
        print(keyword_scores)
        print()
        
def main():
    file_path = 'datasets/Korea_DB_0413.csv'
    documents = load_documents(file_path)
    preprocessor = Preprocess()
    processed_documents = preprocessor.finalpreprocess(documents)
    exclude_words = ['뉴시스', '기자', '뉴스', '동아']
    filtered_documents = filter_documents(processed_documents, exclude_words)
    apply_text_tank(2/datasets/Korea_DB_0413.csv, "4월 10일 투표")
    
if __name__ == "__main__":
    main()

# %%
filtered_documents

# %%
import pagerank
import csv
import collections

def textrank(document, window_size=2, rsp=0.15):
    '''
    This function accepts a string representation
    of a document and three hyperperameters as input.
    It returns Pandas matrix (that can be treated
    as a dictionary) that maps words in the
    document to their associated TextRank significance
    scores. Note that only words that are classified
    as having relevant POS tags are present in the
    map.
    '''
        
    # Build a weighted graph where nodes are words and
    # edge weights are the number of times words cooccur
    # within a window of predetermined size. In doing so
    # we double count each coocurrence, but that will not
    # alter relative weights which ultimately determine
    # TextRank scores.
    words = document
    edge_weights = collections.defaultdict(lambda: collections.Counter())
    for index, word in enumerate(words):
        for other_index in range(index - window_size, index + window_size + 1):
            if other_index >= 0 and other_index < len(words) and other_index != index:
                other_word = words[other_index]
                edge_weights[word][other_word] += 1.0

    # Apply PageRank to the weighted graph:
    word_probabilities = pagerank.power_iteration(edge_weights, rsp=rsp)
    word_probabilities.sort_values(ascending=False)

    return word_probabilities
    
def apply_text_tank(documents, title="a document"):
    print()
    print("Applying TextRank to \"%s\" ..." % title)
    
    for doc in documents:
        document = doc['article']
        keyword_scores = textrank(document)
        
        print()
        header = "Keyword Significance Scores for \"%s\":" % doc['title']
        print(header)
        print("-" * len(header))
        print(keyword_scores)
        print()

def load_documents(file_path):
    documents = []
    with open(file_path, mode='r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            title = row['title']
            article = row['article']
            documents.append({'title': title, 'article': article})
    return documents

def main():
    file_path = 'datasets/preprocessed.csv'
    documents = load_documents(file_path)
    apply_text_tank(documents, "4월 10일 투표")
    
if __name__ == "__main__":
    main()
# Out:
# Applying TextRank to "4월 10일 투표" ...
#
# Keyword Significance Scores for "조태열-블링컨 첫 통화…“한미 동맹 더욱 심화·발전”":
# ----------------------------------------------------------------
# 취    0.005755
# 임    0.010792
#      0.281809
# 인    0.008279
# 사    0.016701
#        ...
# 응    0.003055
# 보    0.004990
# 결    0.003145
# 행    0.003420
# 견    0.002889
# Length: 124, dtype: float64
#
#
# Keyword Significance Scores for "조국 “민주, 총선서 포용력 발휘해 반윤연대 꾸려야”":
# ----------------------------------------------------------------
# 정    0.026972
# 책    0.008983
#      0.274561
# 싱    0.003169
# 크    0.005612
#        ...
# 여    0.002074
# 달    0.002061
# 식    0.002080
# 범    0.003255
# 예    0.001972
# Length: 172, dtype: float64
#
#
# Keyword Significance Scores for "‘재산신고 누락’ 이균용 전 대법원장 후보자 경고 처분":
# -----------------------------------------------------------------
# 상    0.007658
# 장    0.028676
#      0.268016
# 주    0.010837
# 식    0.011314
#        ...
# 통    0.004234
# 일    0.004541
# 간    0.004393
# 백    0.004523
# 기    0.003674
# Length: 88, dtype: float64
#
#
# Keyword Significance Scores for "민주 윤리감찰단, ‘성희롱 발언 논란’ 현근택 대면 조사":
# ------------------------------------------------------------------
# 피    0.005679
# 해    0.014371
# 자    0.018483
#      0.275220
# 출    0.011442
#        ...
# 락    0.006838
# 명    0.007160
# 재    0.004315
# 표    0.004227
# 산    0.004338
# Length: 90, dtype: float64
#
#
# Keyword Significance Scores for "대통령실 “가장 중요한건 물가 안정…의료·주거 생계비 줄일 것”":
# ----------------------------------------------------------------------
# 성    0.009673
# 태    0.005957
#      0.270845
# 신    0.006197
# 임    0.009792
#        ...
# 상    0.002981
# 황    0.002803
# 검    0.002586
# 치    0.002741
# 속    0.001873
# Length: 150, dtype: float64
#
#
# Keyword Significance Scores for "“이태원 참사 특별법, 총선용 악용법”…尹, 거부권 행사 가능성":
# ----------------------------------------------------------------------
# 보    0.005623
# 기    0.004641
#      0.267747
# 윤    0.002415
# 석    0.002338
#        ...
# 후    0.002174
# 가    0.002098
# 촉    0.002144
# 김    0.002536
# 은    0.002103
# Length: 158, dtype: float64
#
#
# Keyword Significance Scores for "법원, 대통령실 특활비·수의계약 공개 판결…“국익침해 우려 없다”":
# -----------------------------------------------------------------------
# 뉴    0.007228
# 스    0.007335
# 타    0.007597
# 파    0.007722
#      0.274147
#        ...
# 함    0.002431
# 머    0.002358
# 침    0.002398
# 불    0.002449
# 복    0.002456
# Length: 130, dtype: float64
#
#
# Keyword Significance Scores for "이재명, 예비후보자 심사 통과…‘1심 실형’ 황운하·‘뇌물 기소’ 노웅래도":
# ----------------------------------------------------------------------------
# 이    0.010434
# 재    0.008474
# 명    0.006084
#      0.251493
# 더    0.004610
#        ...
# 군    0.002674
# 리    0.002771
# 예    0.002766
# 등    0.002891
# 록    0.002857
# Length: 134, dtype: float64
#
#
# Keyword Significance Scores for "돛 올린 우주항공청 “5월 말 개청 목표… 올해 약 8000억 원 투입 예정”":
# ------------------------------------------------------------------------------
# 보    0.007521
# 기    0.020317
#      0.272599
# 이    0.011534
# 종    0.003242
#        ...
# 달    0.001693
# 강    0.001617
# 도    0.001901
# 약    0.002091
# 최    0.001950
# Length: 164, dtype: float64
#
#
# Keyword Significance Scores for "‘코인 논란’ 김남국에 2차 강제조정…법원 “유감 표시하고 재발 방지를”":
# ---------------------------------------------------------------------------
# 남    0.008951
# 국    0.013331
#      0.274587
# 무    0.007403
# 소    0.011348
#        ...
# 려    0.003694
# 월    0.003593
# 급    0.003782
# 압    0.003852
# 류    0.003923
# Length: 106, dtype: float64
#
#
# Keyword Significance Scores for "민주 강성지지층 “왕수박 나갔다, 이제 잔수박 정리”":
# ----------------------------------------------------------------
# 더    0.002696
# 불    0.005810
# 어    0.003896
# 민    0.026849
# 주    0.018238
#        ...
# 도    0.003349
# 타    0.003407
# 생    0.003254
# 경    0.003316
# 복    0.003078
# Length: 129, dtype: float64
#
#
# Keyword Significance Scores for "탈당 기자회견서 결연한 모습 보인 이낙연[청계천 옆 사진관]":
# --------------------------------------------------------------------
# 보    0.001750
# 기    0.014528
#      0.265857
# 이    0.012278
# 낙    0.005054
#        ...
# 경    0.002617
# 호    0.002705
# 량    0.004048
# 탑    0.002768
# 승    0.002665
# Length: 130, dtype: float64
#
#
# Keyword Significance Scores for "‘한동훈 영입 1호’ 박상수 “악의적인 것은 책임 물어야…허위 날조 대응할 것”[중립기어 라이브]":
# -----------------------------------------------------------------------------------------
# 한    0.003030
# 동    0.008208
# 훈    0.001002
#      0.271114
# 대    0.006459
#        ...
# 콘    0.000953
# 텐    0.000944
# 츠    0.000969
# 램    0.000648
# 차    0.000651
# Length: 334, dtype: float64
#
#
# Keyword Significance Scores for "5·18조사위 “‘5월 광주’ 발포 책임자 전두환 확인…입증자료 부족”":
# --------------------------------------------------------------------------
# 민    0.003941
# 주    0.010928
# 화    0.003472
#      0.271687
# 운    0.003421
#        ...
# 파    0.001463
# 향    0.001456
# 편    0.001521
# 범    0.001429
# 례    0.001504
# Length: 195, dtype: float64
#
#
# Keyword Significance Scores for "이준석, 이재명 피습 특검에 “민주당, ‘특검 남발’ 문제의식 가져야”":
# --------------------------------------------------------------------------
# 수    0.017861
# 사    0.038937
#      0.261666
# 실    0.006898
# 관    0.009501
#        ...
# 글    0.004272
# 홍    0.004752
# 익    0.004604
# 내    0.004290
# 국    0.006557
# Length: 90, dtype: float64
#
#
# Keyword Significance Scores for "민주 검증위, ‘1심 의원직 상실형’ 황운하에 적격…노웅래도 통과":
# -----------------------------------------------------------------------
# 의    0.023744
# 원    0.024439
#      0.269808
# 청    0.007893
# 와    0.007702
#        ...
# 염    0.002879
# 태    0.002650
# 영    0.002667
# 경    0.001990
# 무    0.002029
# Length: 151, dtype: float64
#
#
# Keyword Significance Scores for "與공관위, 10명중 4명이 법조인 출신…당내선 중립성 우려 지적도":
# -----------------------------------------------------------------------
# 총    0.006823
# 선    0.006394
#      0.265100
# 공    0.017326
# 천    0.006161
#        ...
# 생    0.002264
# 각    0.002202
# 점    0.002354
# 김    0.002716
# 준    0.002176
# Length: 156, dtype: float64
#
#
# Keyword Significance Scores for "“업적들 무너뜨릴 것”“정계 은퇴하라”… 민주, 이낙연 탈당에 날선 ‘비난’":
# -----------------------------------------------------------------------------
# 보    0.003510
# 기    0.010313
#      0.267669
# 이    0.021884
# 낙    0.007200
#        ...
# 실    0.002750
# 반    0.002699
# 황    0.002853
# 과    0.002903
# 휘    0.002424
# Length: 122, dtype: float64
#
#
# Keyword Significance Scores for "조태용 “대공수사권, 국정원으로 복원돼야”…엑손모빌 의혹엔 “만난적 없어”":
# ----------------------------------------------------------------------------
# 보    0.022830
# 기    0.008248
#      0.262993
# 조    0.008611
# 태    0.005859
#        ...
# 라    0.002846
# 윤    0.002618
# 열    0.002609
# 요    0.002321
# 비    0.002347
# Length: 143, dtype: float64
#
#
# Keyword Significance Scores for "尹대통령 “자유시장 경제, 국민 모두 다 잘살게 되는 시스템”":
# ---------------------------------------------------------------------
# 윤    0.003631
# 석    0.006679
# 열    0.004297
#      0.274176
# 대    0.018621
#        ...
# 최    0.002490
# 총    0.002715
# 리    0.002796
# 획    0.002505
# 참    0.002348
# Length: 129, dtype: float64
#
#
# Keyword Significance Scores for "민주, 현역의원 평가 마무리…컷오프 대상 하위 20% 통보설에 당 ‘술렁’":
# ----------------------------------------------------------------------------
# 보    0.013799
# 기    0.006907
#      0.275512
# 이    0.008848
# 재    0.002497
#        ...
# 조    0.002516
# 면    0.002737
# 접    0.002735
# 규    0.002773
# 영    0.002257
# Length: 139, dtype: float64
#
#
# Keyword Significance Scores for "서울 정신병원서 사망자 명의로 마약류 처방하다 덜미":
# ---------------------------------------------------------------
# 서    0.010556
# 울    0.010712
# 시    0.013581
#      0.266856
# 강    0.011800
#        ...
# 조    0.003434
# 후    0.003795
# 유    0.003647
# 재    0.003380
# 통    0.003025
# Length: 106, dtype: float64
#
#
# Keyword Significance Scores for "붉은 넥타이 이낙연 “민주당 본래 가치 찾겠다”…지지자 “힘내세요”":
# ------------------------------------------------------------------------
# 이    0.020213
# 낙    0.004249
# 연    0.006849
#      0.265407
# 더    0.005102
#        ...
# 증    0.002982
# 행    0.003120
# 달    0.003043
# 내    0.003116
# 세    0.003288
# Length: 119, dtype: float64
#
#
# Keyword Significance Scores for "운동후 청사서 야근비 신청?…감사원, 부당 수령한 공무원 198명 적발":
# --------------------------------------------------------------------------
# 보    0.004770
# 기    0.009805
#      0.265467
# 서    0.016078
# 울    0.013575
#        ...
# 권    0.003952
# 숙    0.003877
# 경    0.003517
# 도    0.003560
# 예    0.002876
# Length: 110, dtype: float64
#
#
# Keyword Significance Scores for "이낙연 “양당 독점구도 깨는 의석수 필요…지역구 전부 출마”[일문일답]":
# --------------------------------------------------------------------------
# 이    0.009480
# 낙    0.001611
# 연    0.005430
#      0.274137
# 더    0.001147
#        ...
# 타    0.001062
# 파    0.001104
# 폐    0.000946
# 것    0.001010
# 험    0.000964
# Length: 265, dtype: float64
#
#
# Keyword Significance Scores for "천하람 “개혁신당 12일 인재 영입 발표…아주 좋은 분”[중립기어 라이브]":
# ----------------------------------------------------------------------------
# 개    0.003508
# 혁    0.002309
# 신    0.004530
# 당    0.006677
#      0.274964
#        ...
# 콘    0.000861
# 텐    0.000851
# 츠    0.000856
# 램    0.000592
# 췌    0.000566
# Length: 371, dtype: float64
#
#
# Keyword Significance Scores for "中은 조용한데 러시아는 “왕이와 한반도 문제 논의”…온도 차이 이유는?":
# --------------------------------------------------------------------------
# 중    0.020305
# 국    0.025937
#      0.269041
# 러    0.012258
# 시    0.014247
#        ...
# 검    0.001870
# 토    0.001899
# 강    0.001716
# 각    0.002687
# 소    0.001530
# Length: 174, dtype: float64
#
#
# Keyword Significance Scores for "5월 개청 우주항공청…2045년 화성 탐사 도전 선언한 한국형 나사 ‘KASA’":
# -------------------------------------------------------------------------------
# 이    0.009710
# 종    0.006050
# 호    0.006273
#      0.277905
# 과    0.008111
#        ...
# 망    0.002184
# 쟁    0.002085
# 세    0.002087
# 래    0.002039
# 척    0.002036
# Length: 160, dtype: float64
#
#
# Keyword Significance Scores for "정부, 유엔 ‘中인권검토’ 앞두고 첫 서면질의…北 강제북송 적시":
# ----------------------------------------------------------------------
# 시    0.009240
# 민    0.013849
# 사    0.015757
# 회    0.009275
#      0.273311
#        ...
# 리    0.003012
# 핑    0.003018
# 련    0.002339
# 무    0.002245
# 위    0.002406
# Length: 131, dtype: float64
#
#
# Keyword Significance Scores for "이낙연 신당 구상…‘타협의 다당제·분권형 대통령제’ 제시":
# ------------------------------------------------------------------
# 이    0.007399
# 낙    0.004247
# 연    0.006667
#      0.272739
# 더    0.006553
#        ...
# 단    0.002853
# 체    0.002973
# 해    0.003163
# 말    0.003323
# 씀    0.003120
# Length: 130, dtype: float64
#
#
# Keyword Significance Scores for "노영민 文청와대 비서실장, 청주 상당 출사표…“정권 심판”":
# -------------------------------------------------------------------
# 이    0.010689
# 낙    0.002452
# 연    0.006500
#      0.271864
# 탈    0.004311
#        ...
# 야    0.001948
# 양    0.001906
# 인    0.001798
# 빅    0.001958
# 매    0.001964
# Length: 174, dtype: float64
#
#
# Keyword Significance Scores for "‘이낙연 탈당’에 광주 정치권 맹비난…“정치적 반란행위”":
# ------------------------------------------------------------------
# 이    0.015343
# 낙    0.006099
# 연    0.008611
#      0.271789
# 더    0.003656
#        ...
# 영    0.001319
# 활    0.001422
# 투    0.001675
# 쟁    0.001607
# 점    0.001379
# Length: 204, dtype: float64
#
#
# Keyword Significance Scores for "친윤 이철규, ‘윤심 공천’ 우려에 “당 계파 없어…한동훈 교감 안 해”":
# ---------------------------------------------------------------------------
# 관    0.010624
# 위    0.022709
#      0.273676
# 인    0.014155
# 선    0.007796
#        ...
# 영    0.005579
# 입    0.005365
# 체    0.003486
# 제    0.003529
# 유    0.002911
# Length: 116, dtype: float64
#
#
# Keyword Significance Scores for "이재명, 조연우 위원장 별세에 “남은 숙제는 저와 당에 맡겨달라”":
# -----------------------------------------------------------------------
# 이    0.022551
# 재    0.010388
# 명    0.008147
#      0.261517
# 더    0.008650
#        ...
# 한    0.005425
# 편    0.005085
# 퇴    0.004511
# 택    0.005052
# 료    0.003420
# Length: 84, dtype: float64
#
#
# Keyword Significance Scores for "“제2안철수의 길”…민주당, 이낙연 탈당 비난 봇물":
# ---------------------------------------------------------------
# 이    0.015254
# 낙    0.005863
# 연    0.006264
#      0.275628
# 민    0.017480
#        ...
# 한    0.002124
# 진    0.001993
# 결    0.002643
# 제    0.001792
# 활    0.001879
# Length: 177, dtype: float64
#
#
# Keyword Significance Scores for "빅텐트 ‘기호3번’ 노린다…이낙연과 3인방, 이준석도 ‘연대’":
# ---------------------------------------------------------------------
# 이    0.012865
# 낙    0.005850
# 연    0.012740
#      0.270848
# 더    0.005039
#        ...
# 보    0.003676
# 출    0.003247
# 재    0.003185
# 인    0.003198
# 역    0.002962
# Length: 120, dtype: float64
#
#
# Keyword Significance Scores for "이낙연 “누군가는 가야 길이 된다…새로운 길 동행해달라”":
# ------------------------------------------------------------------
# 이    0.012504
# 낙    0.006700
# 연    0.007469
#      0.264554
# 더    0.007512
#        ...
# 령    0.004607
# 권    0.004889
# 유    0.004673
# 계    0.004622
# 입    0.004649
# Length: 96, dtype: float64
#
#
# Keyword Significance Scores for "김은혜·방문규·염태영 등 출사표…경기도에 공직자출신 ‘출마 러시’":
# -----------------------------------------------------------------------
# 국    0.007363
# 회    0.008513
# 의    0.007663
# 원    0.011236
#      0.257715
#        ...
# 오    0.002466
# 늘    0.002257
# 련    0.002217
# 추    0.002283
# 처    0.001989
# Length: 147, dtype: float64
#
#
# Keyword Significance Scores for "최상목 “50인 미만 기업 중대법 유예, 국회서 신속 처리해야”":
# ----------------------------------------------------------------------
# 부    0.014332
# 총    0.008153
# 리    0.014278
#      0.264329
# 중    0.026289
#        ...
# 립    0.002732
# 극    0.002915
# 반    0.003097
# 영    0.002983
# 종    0.002015
# Length: 137, dtype: float64
#
#
# Keyword Significance Scores for "육·해군총장, 北포격에 서남해역 경계태세 점검…“합동작전 강화”":
# ----------------------------------------------------------------------
# 육    0.009583
# 군    0.014814
#      0.284234
# 참    0.006527
# 모    0.007784
#        ...
# 터    0.002537
# 축    0.003912
# 선    0.002175
# 첨    0.002523
# 단    0.002454
# Length: 143, dtype: float64
#
#
# Keyword Significance Scores for "與 공관위원장 “외부 공관위원 총선 불출마…윤심 개입 없어”":
# --------------------------------------------------------------------
# 합    0.002995
# 류    0.003397
#      0.279684
# 우    0.007615
# 려    0.007220
#        ...
# 절    0.002399
# 차    0.002395
# 시    0.002457
# 행    0.002454
# 택    0.002173
# Length: 145, dtype: float64
#
#
# Keyword Significance Scores for "당정 “연체채무 전액 상환자 최대 290만명 신용회복”":
# -----------------------------------------------------------------
# 김    0.005261
# 주    0.011622
# 현    0.008030
#      0.280535
# 금    0.011732
#        ...
# 약    0.006305
# 결    0.006739
# 조    0.007008
# 치    0.006804
# 행    0.004322
# Length: 70, dtype: float64
#
#
# Keyword Significance Scores for "당정, 코로나 소상공인 신용사면 검토…“통신채무 채무조정 고려”":
# ----------------------------------------------------------------------
# 김    0.002837
# 주    0.003064
# 현    0.003302
#      0.279958
# 금    0.020015
#        ...
# 병    0.001868
# 합    0.001769
# 보    0.001751
# 예    0.001755
# 재    0.001952
# Length: 161, dtype: float64
#
#
# Keyword Significance Scores for "박민식 前보훈부장관 “영등포을 출마…운동권 세력과 정면승부”":
# --------------------------------------------------------------------
# 박    0.004434
# 민    0.017739
# 식    0.005385
#      0.264698
# 국    0.013406
#        ...
# 학    0.005280
# 년    0.003213
# 물    0.003259
# 표    0.003211
# 우    0.002511
# Length: 119, dtype: float64
#
#
# Keyword Significance Scores for "한동훈 비대위 14일 첫 고위당정…설 민생대책 논의":
# ---------------------------------------------------------------
# 한    0.009445
# 동    0.012008
# 훈    0.006585
#      0.266205
# 국    0.014267
#        ...
# 우    0.003823
# 홍    0.003750
# 보    0.003431
# 근    0.003315
# 체    0.003351
# Length: 111, dtype: float64
#
#
# Keyword Significance Scores for "라오스 골든트라이앵글 ‘여행금지’ 발령 예정…“취업사기 급증”":
# ---------------------------------------------------------------------
# 라    0.021385
# 오    0.009044
# 스    0.021256
#      0.252534
# 골    0.005721
#        ...
# 레    0.003924
# 잔    0.002314
# 팔    0.002362
# 타    0.002399
# 동    0.001937
# Length: 143, dtype: float64
#
#
# Keyword Significance Scores for "정부, ‘취업사기 극성’ 라오스 북부 골든트라이앵글 2월부터 여행금지령":
# --------------------------------------------------------------------------
# 가    0.009716
# 자    0.007828
# 지    0.025255
# 구    0.010012
#      0.260744
#        ...
# 테    0.001865
# 속    0.002513
# 앞    0.001932
# 으    0.001943
# 황    0.001817
# Length: 180, dtype: float64
#
#
# Keyword Significance Scores for "러시아 관광객에 문 연 북한…연내 국경 개방 확대 조짐 지속":
# --------------------------------------------------------------------
# 북    0.021528
# 한    0.021011
#      0.270131
# 마    0.002879
# 식    0.002861
#        ...
# 와    0.001653
# 향    0.001751
# 여    0.001806
# 반    0.002702
# 때    0.001660
# Length: 175, dtype: float64
#
#
# Keyword Significance Scores for "김하중 변호사, ‘탈당’ 이원욱 지역구 출마 선언":
# --------------------------------------------------------------
# 김    0.006824
# 하    0.007590
# 중    0.011858
#      0.262351
# 변    0.017147
#        ...
# 조    0.004858
# 처    0.004764
# 임    0.005537
# 정    0.005306
# 봉    0.003952
# Length: 89, dtype: float64
#
#
# Keyword Significance Scores for "이낙연 탈당 “민주당, 1인-방탄정당 변질”":
# -----------------------------------------------------------
# 이    0.011764
# 낙    0.003636
# 연    0.003881
#      0.273613
# 더    0.005683
#        ...
# 태    0.002237
# 라    0.002325
# 고    0.002159
# 소    0.002291
# 영    0.001898
# Length: 163, dtype: float64
#
#
# Keyword Significance Scores for "강정애, 14개 중앙보훈단체 잇달아 방문…보훈업무 첫 공식 행보":
# ----------------------------------------------------------------------
# 강    0.004344
# 정    0.018200
#      0.276360
# 국    0.019058
# 가    0.016013
#        ...
# 운    0.002546
# 데    0.002516
# 책    0.002570
# 설    0.002600
# 개    0.002472
# Length: 143, dtype: float64
#
#
# Keyword Significance Scores for "조태용 “선거결과 영향 미치는 정치관여 안 할 것”":
# ---------------------------------------------------------------
# 조    0.008233
# 태    0.005968
# 용    0.006511
#      0.258588
# 국    0.024557
#        ...
# 임    0.003772
# 분    0.004227
# 충    0.004219
# 얘    0.004224
# 기    0.004254
# Length: 101, dtype: float64
#
#
# Keyword Significance Scores for "조태용 “北 김정은 체제 나름의 안정성 있어…올해 도발 수위 높아질 듯”":
# ---------------------------------------------------------------------------
# 조    0.008771
# 태    0.005743
# 용    0.004359
#      0.275391
# 국    0.010873
#        ...
# 휘    0.002759
# 판    0.002793
# 타    0.002801
# 설    0.002943
# 명    0.002322
# Length: 136, dtype: float64
#
#
# Keyword Significance Scores for "민주 “尹, 정부 요직 선후배·동기로 도배할 셈인가”":
# ----------------------------------------------------------------
# 신    0.008104
# 임    0.008359
#      0.271416
# 국    0.024810
# 민    0.026665
#        ...
# 성    0.004296
# 골    0.007283
# 품    0.004141
# 용    0.003981
# 경    0.003570
# Length: 87, dtype: float64
#
#
# Keyword Significance Scores for "‘95만채 공급’ 재건축으로만?…리모델링 추진 100만명 뿔났다":
# ----------------------------------------------------------------------
# 서    0.008235
# 울    0.008388
#      0.280474
# 영    0.002930
# 등    0.003001
#        ...
# 때    0.002461
# 문    0.002431
# 역    0.002526
# 할    0.002559
# 강    0.002151
# Length: 142, dtype: float64
#
#
# Keyword Significance Scores for "‘친윤 핵심’ 이철규 공관위 합류… 한동훈 “당 이끄는 건 저”":
# ----------------------------------------------------------------------
# 이    0.011131
# 철    0.005388
# 규    0.005567
#      0.273495
# 국    0.007645
#        ...
# 득    0.002155
# 력    0.002138
# 말    0.002117
# 씀    0.002180
# 박    0.001500
# Length: 168, dtype: float64
#
#
# Keyword Significance Scores for "김종민 “이낙연 신당 합류…대통령 만드는 걸로 오해할 수도”":
# --------------------------------------------------------------------
# 위    0.004267
# 험    0.004922
#      0.278797
# 결    0.005346
# 단    0.005260
#        ...
# 객    0.003434
# 여    0.003628
# 군    0.003658
# 활    0.003603
# 약    0.003315
# Length: 124, dtype: float64
#
#
# Keyword Significance Scores for "조태용 청문회, ‘병역·증여세’ 등 자료제출 공방…1시간만 정회":
# ----------------------------------------------------------------------
# 재    0.006088
# 산    0.006149
#      0.275593
# 자    0.029650
# 료    0.018058
#        ...
# 합    0.001970
# 필    0.001995
# 선    0.002212
# 언    0.002267
# 속    0.001786
# Length: 147, dtype: float64
#
#
# Keyword Significance Scores for "민주당 129명, 이낙연 탈당 만류…“분열의 길 이끌어선 안돼”":
# ----------------------------------------------------------------------
# 강    0.010420
# 득    0.005529
# 구    0.009578
#      0.265877
# 더    0.004783
#        ...
# 식    0.003033
# 언    0.002896
# 직    0.002832
# 출    0.003193
# 김    0.003421
# Length: 122, dtype: float64
#
#
# Keyword Significance Scores for "탈당 이원욱 “이재명-정성호 병상문자, 국정농단과 뭐가 다르냐”":
# ----------------------------------------------------------------------
# 이    0.018305
# 재    0.008921
# 명    0.009626
#      0.265289
# 더    0.006026
#        ...
# 만    0.002293
# 마    0.002526
# 막    0.002794
# 외    0.002817
# 통    0.002577
# Length: 148, dtype: float64
#
#
# Keyword Significance Scores for "日, 북한 미사일 발사 등 감시할 정보위성 발사…궤도 진입 성공":
# ----------------------------------------------------------------------
# 고    0.009169
# 도    0.015664
#      0.288763
# 지    0.010768
# 구    0.007582
#        ...
# 대    0.004863
# 체    0.004862
# 난    0.004616
# 실    0.004827
# 패    0.004827
# Length: 87, dtype: float64
#
#
# Keyword Significance Scores for "2020년 北 국경폐쇄후 처음으로 러 관광객들 북한으로 스키여행":
# ----------------------------------------------------------------------
# 무    0.007961
# 기    0.009577
#      0.265228
# 공    0.006611
# 급    0.003786
#        ...
# 거    0.002616
# 본    0.002379
# 성    0.002661
# 명    0.002784
# 표    0.001911
# Length: 136, dtype: float64
#
#
# Keyword Significance Scores for "文 전 대통령, 홍익표 만나 “조금 더 통합적으로 당 운영해야”":
# ----------------------------------------------------------------------
# 문    0.007881
# 재    0.011078
# 인    0.009103
#      0.265574
# 대    0.033623
#        ...
# 격    0.004336
# 유    0.004777
# 김    0.006292
# 혜    0.005153
# 린    0.004201
# Length: 107, dtype: float64
#
#
# Keyword Significance Scores for "대검, ‘정치적 중립위반’ 김상민 검사 중징계 청구":
# ---------------------------------------------------------------
# 검    0.038639
# 찰    0.015355
# 청    0.007797
#      0.285247
# 정    0.011894
#        ...
# 록    0.003700
# 외    0.003598
# 접    0.003675
# 촉    0.003675
# 봉    0.002435
# Length: 108, dtype: float64
#
#
# Keyword Significance Scores for "이낙연 탈당 후 양산 달려간 홍익표…文 “하나돼야 총선 승리”":
# ---------------------------------------------------------------------
# 문    0.006213
# 재    0.006545
# 인    0.008332
#      0.273994
# 대    0.031900
#        ...
# 소    0.002702
# 관    0.002640
# 련    0.002618
# 말    0.002709
# 씀    0.002709
# Length: 142, dtype: float64
#
#
# Keyword Significance Scores for "‘뇌물 수수 의혹’ 노웅래 “위헌법률심판 제청” vs 검찰 “재판 지연 의도”":
# ------------------------------------------------------------------------------
# 노    0.003749
# 웅    0.004135
# 래    0.004822
#      0.258249
# 더    0.004717
#        ...
# 명    0.002549
# 례    0.002558
# 난    0.002649
# 해    0.002793
# 속    0.002675
# Length: 129, dtype: float64
#
#
# Keyword Significance Scores for "野공관위 “증오-폭력발언 공천에 반영”…계파 잡음엔 “친명 비명 없다”":
# --------------------------------------------------------------------------
# 임    0.003099
# 혁    0.003426
# 백    0.003812
#      0.271789
# 더    0.003642
#        ...
# 좌    0.002396
# 우    0.002547
# 분    0.002677
# 령    0.002488
# 윤    0.002136
# Length: 161, dtype: float64
#
#
# Keyword Significance Scores for "대통령실 “신년 기자회견·제2부속실 여러 가지로 검토중”":
# ------------------------------------------------------------------
# 용    0.006052
# 산    0.006665
#      0.270393
# 대    0.029551
# 통    0.022463
#        ...
# 선    0.004490
# 약    0.004576
# 출    0.004663
# 범    0.004769
# 폐    0.003799
# Length: 90, dtype: float64
#
#
# Keyword Significance Scores for "대통령실, ‘바이든-날리면’ 정정보도 선고에 “정부·외교 신뢰 회복 계기”":
# ----------------------------------------------------------------------------
# 이    0.010343
# 도    0.022121
# 우    0.004670
#      0.277155
# 홍    0.003270
#        ...
# 다    0.002602
# 하    0.002416
# 루    0.002344
# 급    0.002182
# 혜    0.001991
# Length: 164, dtype: float64
#
#
# Keyword Significance Scores for "野탈당 3인 ‘미래대연합’, 이낙연 ‘새로운 미래’…합종연횡 본격화":
# ------------------------------------------------------------------------
# 더    0.003625
# 불    0.004970
# 어    0.003992
# 민    0.009191
# 주    0.006085
#        ...
# 결    0.001689
# 텐    0.001839
# 트    0.001927
# 필    0.001846
# 리    0.001275
# Length: 194, dtype: float64
#
#
# Keyword Significance Scores for "대통령실, ‘바이든 날리면’ 정정보도 판결에 “정부신뢰 회복 계기”":
# ------------------------------------------------------------------------
# 윤    0.004447
# 석    0.009281
# 열    0.005520
#      0.276401
# 대    0.017876
#        ...
# 향    0.003695
# 허    0.003728
# 책    0.003491
# 임    0.003602
# 적    0.002367
# Length: 118, dtype: float64
#
#
# Keyword Significance Scores for "美, 北 탄도미사일 수송 러 국영항공사 등 제재":
# -------------------------------------------------------------
# 토    0.003571
# 니    0.003861
#      0.266849
# 미    0.014177
# 국    0.017053
#        ...
# 래    0.002639
# 워    0.003273
# 싱    0.003247
# 턴    0.003340
# 특    0.002632
# Length: 130, dtype: float64
#
#
# Keyword Significance Scores for "한동훈 지지율 22%, 이재명 턱밑…피습 ‘동정론’은 없었다":
# --------------------------------------------------------------------
# 한    0.004048
# 동    0.009831
# 훈    0.003203
#      0.276999
# 국    0.008288
#        ...
# 페    0.002196
# 참    0.002096
# 하    0.002411
# 면    0.002579
# 된    0.002096
# Length: 154, dtype: float64
#
#
# Keyword Significance Scores for "與, 황운하·노웅래 출마 적격 판정에 “불공정 공천 현실화”":
# --------------------------------------------------------------------
# 심    0.008052
# 사    0.015044
#      0.277078
# 기    0.010964
# 준    0.004390
#        ...
# 다    0.002951
# 음    0.003170
# 총    0.002967
# 쟁    0.002698
# 종    0.002912
# Length: 128, dtype: float64
#
#
# Keyword Significance Scores for "문재인 “통합적 운영해야”…홍익표 “국가원로 역할 해달라”":
# -------------------------------------------------------------------
# 홍    0.004072
# 익    0.004480
# 표    0.020337
#      0.268573
# 경    0.008580
#        ...
# 올    0.002995
# 거    0.002949
# 교    0.003148
# 노    0.003246
# 력    0.003292
# Length: 117, dtype: float64
#
#
# Keyword Significance Scores for "“저도 한가입니다” 한동훈 한마디에 빵 터졌다":
# ------------------------------------------------------------
# 국    0.009543
# 민    0.017340
#      0.260683
# 한    0.020656
# 동    0.008805
#        ...
# 아    0.003864
# 합    0.003594
# 개    0.003364
# 혜    0.003650
# 선    0.002969
# Length: 105, dtype: float64
#
#
# Keyword Significance Scores for "양산 통도사 찾은 한동훈 “불교, 우리 전통문화와 정신의 핵심…중요하게 생각”":
# ------------------------------------------------------------------------------
# 통    0.017550
# 도    0.017272
# 사    0.018038
#      0.260865
# 조    0.008382
#        ...
# 윤    0.004154
# 석    0.005645
# 박    0.004098
# 출    0.004133
# 진    0.003992
# Length: 102, dtype: float64
#
#
# Keyword Significance Scores for "‘바이든 보도’ 정정판결에 민주 “진위 모른다며 무슨 근거로”":
# ---------------------------------------------------------------------
# 윤    0.006131
# 석    0.006620
# 열    0.007017
#      0.266285
# 대    0.019335
#        ...
# 조    0.003202
# 절    0.003380
# 차    0.003380
# 청    0.003434
# 구    0.003542
# Length: 108, dtype: float64
#
#
# Keyword Significance Scores for "정청래 “경찰, 이재명 핏자국 지워 증거인멸” 특검 거론…與 “음모론 여론몰이”":
# -------------------------------------------------------------------------------
# 보    0.001680
# 기    0.009316
#      0.273346
# 정    0.009724
# 청    0.007672
#        ...
# 멍    0.002477
# 통    0.002406
# 상    0.002472
# 화    0.002964
# 영    0.002442
# Length: 148, dtype: float64
#
#
# Keyword Significance Scores for "신원식, 국방과학연구소 첫 방문…“초정밀·고위력 무기개발 박차”":
# ----------------------------------------------------------------------
# 순    0.006663
# 직    0.007060
#      0.278352
# 연    0.019945
# 구    0.021813
#        ...
# 이    0.003699
# 날    0.003662
# 그    0.004248
# 동    0.004213
# 안    0.004263
# Length: 109, dtype: float64
#
#
# Keyword Significance Scores for "문재인, 홍익표 만나 “민주당 통합적으로 운영해야” 당부":
# ------------------------------------------------------------------
# 홍    0.004917
# 익    0.005256
# 표    0.023730
#      0.264314
# 더    0.005865
#        ...
# 복    0.004053
# 귀    0.003819
# 유    0.004856
# 충    0.003811
# 격    0.003923
# Length: 105, dtype: float64
#
#
# Keyword Significance Scores for "국힘, ‘바이든 날리면’ 정정보도 판결에 “MBC 사과하라”":
# --------------------------------------------------------------------
# 국    0.024598
# 민    0.019348
#      0.275081
# 윤    0.007950
# 재    0.004589
#        ...
# 치    0.007044
# 책    0.004357
# 임    0.004371
# 산    0.004181
# 강    0.003615
# Length: 103, dtype: float64
#
#
# Keyword Significance Scores for "김무성, 내주 출마 선언…부산 중·영도 격전지 부상":
# ---------------------------------------------------------------
# 김    0.003180
# 무    0.008675
# 성    0.006492
#      0.275040
# 미    0.003588
#        ...
# 생    0.002681
# 교    0.002694
# 육    0.002578
# 흥    0.002307
# 준    0.001843
# Length: 146, dtype: float64
#
#
# Keyword Significance Scores for "이낙연, 신당 가칭 ‘새로운 미래’ 발표…“극단의 정치 타파”":
# ---------------------------------------------------------------------
# 정    0.025440
# 식    0.004918
#      0.270344
# 당    0.052100
# 명    0.011184
#        ...
# 재    0.003634
# 책    0.003499
# 비    0.003586
# 시    0.003602
# 봉    0.002469
# Length: 104, dtype: float64
#
#
# Keyword Significance Scores for "홍익표, 비명 3인·이낙연 탈당에 “강물은 결국 바다에서 만나”":
# ----------------------------------------------------------------------
# 방    0.008911
# 식    0.006106
#      0.270750
# 생    0.013238
# 각    0.013058
#        ...
# 술    0.002883
# 외    0.002881
# 청    0.002744
# 업    0.002470
# 배    0.002353
# Length: 147, dtype: float64
#
#
# Keyword Significance Scores for "허은아, ‘여성 그림 비상구’ 추가에 “국민 세금 갖고 장난하나”":
# -----------------------------------------------------------------------
# 비    0.020510
# 상    0.018009
# 구    0.012785
#      0.261605
# 남    0.007417
#        ...
# 인    0.004543
# 벼    0.004807
# 랑    0.005375
# 강    0.004923
# 조    0.003632
# Length: 99, dtype: float64
#
#
# Keyword Significance Scores for "이태원 특별법 거부권 뜸들이는 尹…“법리적 비판은 별개 문제”":
# ---------------------------------------------------------------------
# 윤    0.003717
# 석    0.004111
# 열    0.004448
#      0.272107
# 대    0.021299
#        ...
# 려    0.003794
# 현    0.002498
# 잘    0.002812
# 못    0.002690
# 보    0.002647
# Length: 130, dtype: float64
#
#
# Keyword Significance Scores for "외교부 “MBC 허위보도 대단히 무책임…외교 신뢰회복 계기”":
# --------------------------------------------------------------------
# 바    0.005339
# 이    0.014857
# 든    0.006304
#      0.277162
# 외    0.018055
#        ...
# 명    0.002723
# 론    0.003129
# 중    0.003173
# 제    0.004145
# 유    0.002691
# Length: 131, dtype: float64
#
#
# Keyword Significance Scores for "한동훈 방문한 양산 통도사…국힘 지지자 “힘내라” 연호":
# -----------------------------------------------------------------
# 한    0.008570
# 동    0.012825
# 훈    0.009466
#      0.259189
# 국    0.006230
#        ...
# 참    0.003174
# 만    0.002940
# 식    0.003270
# 덕    0.003300
# 난    0.002949
# Length: 114, dtype: float64
#
#
# Keyword Significance Scores for "이재명측 “당분간 출석 어렵다” vs 재판부 “그러면 끝 없어…李없어도 23일 재개”":
# ----------------------------------------------------------------------------------
# 흉    0.003685
# 기    0.014727
#      0.272360
# 피    0.006239
# 습    0.008541
#        ...
# 산    0.003082
# 덕    0.003299
# 항    0.002834
# 격    0.003027
# 경    0.002212
# Length: 122, dtype: float64
#
#
# Keyword Significance Scores for "전·현직 의원부터 장·차관 출신 득실…국힘 내부 경쟁 치열한 ‘이곳’은?":
# ---------------------------------------------------------------------------
# 한    0.002216
# 동    0.004255
# 훈    0.004562
#      0.270093
# 국    0.009056
#        ...
# 복    0.001698
# 청    0.001703
# 반    0.001916
# 면    0.001873
# 백    0.001653
# Length: 175, dtype: float64
#
#
# Keyword Significance Scores for "뷰티 전문가로 변신한 북한 여성 돌격대원[주성하의 북에서 온 이웃]":
# ------------------------------------------------------------------------
# 한    0.006010
# 국    0.011822
#      0.277162
# 입    0.002469
# 피    0.004982
#        ...
# 확    0.000784
# 효    0.000794
# 또    0.000911
# 래    0.000910
# 획    0.000794
# Length: 321, dtype: float64
#
#
# Keyword Significance Scores for "홍준표 “달빛철도법 대표발의자 무책임, 총선서 책임 물어야”":
# --------------------------------------------------------------------
# 홍    0.003890
# 준    0.004967
# 표    0.016062
#      0.278943
# 대    0.022669
#        ...
# 류    0.003248
# 눈    0.003337
# 애    0.002029
# 력    0.003218
# 입    0.003057
# Length: 145, dtype: float64
#
#
# Keyword Significance Scores for "北 선전매체들, 이틀째 접속 안돼…개편 위한 차단 추측":
# -----------------------------------------------------------------
# 북    0.020203
# 한    0.017864
#      0.265161
# 선    0.029924
# 전    0.023011
#        ...
# 비    0.003726
# 말    0.003427
# 회    0.003502
# 계    0.003332
# 취    0.003325
# Length: 108, dtype: float64
#
#
# Keyword Significance Scores for "조태열 “강제동원 문제, 함께 배 타는 마음으로…日기업 동참해야”":
# -----------------------------------------------------------------------
# 조    0.007186
# 태    0.004097
# 열    0.005764
#      0.280125
# 외    0.009909
#        ...
# 쟁    0.002218
# 요    0.002135
# 획    0.002203
# 운    0.002340
# 데    0.002362
# Length: 156, dtype: float64
#
#
# Keyword Significance Scores for "‘산불 골프 의혹’ 김진태 “수사 이후로 선고 늦춰달라”":
# ------------------------------------------------------------------
# 김    0.005358
# 진    0.007496
# 태    0.007755
#      0.275334
# 상    0.013604
#        ...
# 당    0.004509
# 술    0.003565
# 자    0.003492
# 리    0.003552
# 련    0.002799
# Length: 122, dtype: float64
#
#
# Keyword Significance Scores for "원칙과상식, ‘미래대연합’ 창당…“설 연휴 전 대연합 세력 출범”":
# -----------------------------------------------------------------------
# 탈    0.003074
# 당    0.019707
#      0.283529
# 명    0.004567
# 계    0.005282
#        ...
# 축    0.001625
# 역    0.001557
# 감    0.001488
# 말    0.001853
# 씀    0.001476
# Length: 192, dtype: float64
#
#
# Keyword Significance Scores for "천하람 “개혁신당 20일 창당 완료…이낙연 속도 내서 실기 않기를”":
# ------------------------------------------------------------------------
# 업    0.005275
# 그    0.005615
# 레    0.006342
# 이    0.022580
# 드    0.008362
#        ...
# 치    0.003420
# 미    0.003686
# 래    0.004190
# 보    0.003950
# 탬    0.002932
# Length: 112, dtype: float64
#
#
# Keyword Significance Scores for "‘흉기 피습’ 이재명 “1월 재판 출석 어렵다”…재판부 “그러면 끝이 없다”":
# -----------------------------------------------------------------------------
# 흉    0.005753
# 기    0.016960
#      0.267580
# 피    0.006500
# 습    0.008995
#        ...
# 임    0.003048
# 예    0.005919
# 산    0.003156
# 덕    0.003370
# 격    0.003129
# Length: 121, dtype: float64
#
#
# Keyword Significance Scores for "어딘지도 모르는데 종류도 제각각…행안부 “대피소 공동활용 추진”":
# ----------------------------------------------------------------------
# 재    0.020943
# 난    0.018844
#      0.271993
# 유    0.005220
# 형    0.005294
#        ...
# 음    0.003301
# 티    0.003254
# 맵    0.003068
# 검    0.002779
# 색    0.002771
# Length: 121, dtype: float64
#
#
# Keyword Significance Scores for "‘흉기관통’ 이재명 셔츠, 의료용 쓰레기봉투서 폐기 직전 발견":
# ---------------------------------------------------------------------
# 피    0.011461
# 습    0.010206
#      0.259766
# 당    0.014599
# 시    0.010622
#        ...
# 과    0.004069
# 브    0.004211
# 핑    0.003919
# 설    0.003457
# 혜    0.002855
# Length: 102, dtype: float64
#
#
# Keyword Significance Scores for "김용남, 이준석 품에…“尹에게 국민도 속고 저도 속았다”":
# ------------------------------------------------------------------
# 김    0.002271
# 용    0.004457
# 남    0.002726
#      0.273759
# 국    0.016010
#        ...
# 형    0.001830
# 태    0.001820
# 덩    0.001765
# 투    0.001615
# 너    0.001653
# Length: 192, dtype: float64
#
#
# Keyword Significance Scores for "조태열 “北 도발에 대응 ‘단호·절제’…국제연대가 해답”":
# ------------------------------------------------------------------
# 취    0.002801
# 임    0.005521
#      0.284427
# 기    0.010540
# 자    0.004659
#        ...
# 러    0.001554
# 직    0.001969
# 좌    0.001322
# 념    0.001290
# 독    0.001210
# Length: 223, dtype: float64
#
#
# Keyword Significance Scores for "여당, ‘1호 인재’ 박상수 논란에 “비공개 SNS 발언 검토 논의”":
# -------------------------------------------------------------------------
# 국    0.010985
# 민    0.011602
#      0.277278
# 판    0.010016
# 단    0.007834
#        ...
# 피    0.003475
# 소    0.003570
# 고    0.004211
# 응    0.004057
# 수    0.003025
# Length: 110, dtype: float64
#
#
# Keyword Significance Scores for "與 인재영입위, 3명 인재 영입…이레나·강철호·전상범":
# ----------------------------------------------------------------
# 과    0.007036
# 학    0.016732
#      0.274437
# 법    0.006681
# 조    0.005129
#        ...
# 호    0.001957
# 처    0.002112
# 리    0.002081
# 람    0.002029
# 심    0.002018
# Length: 159, dtype: float64
#
#
# Keyword Significance Scores for "국힘 인재영입위, 이레나·강철호·전상범 영입":
# -----------------------------------------------------------
# 왼    0.001581
# 쪽    0.001944
#      0.278325
# 레    0.004567
# 나    0.003420
#        ...
# 증    0.001752
# 환    0.001707
# 본    0.001668
# 거    0.001641
# 토    0.001831
# Length: 181, dtype: float64
#
#
# Keyword Significance Scores for "멈췄던 ‘대장동 재판’ 1월 말 재개…이재명 출석은 불투명":
# -------------------------------------------------------------------
# 대    0.018384
# 장    0.007298
# 동    0.011549
#      0.273224
# 백    0.002743
#        ...
# 골    0.001837
# 편    0.001804
# 응    0.001858
# 헬    0.001798
# 송    0.001867
# Length: 179, dtype: float64
#
#
# Keyword Significance Scores for "이재명 ‘피습 셔츠’ 부산대병원 아닌 진주서 수거, 왜?":
# ------------------------------------------------------------------
# 피    0.010430
# 습    0.004912
#      0.259046
# 당    0.014118
# 시    0.009716
#        ...
# 멍    0.003964
# 통    0.003553
# 크    0.003361
# 맥    0.003904
# 손    0.003866
# Length: 99, dtype: float64
#
#
# Keyword Significance Scores for "이재명 “혁신·통합 공천으로 이기는 민주당 돼야”":
# --------------------------------------------------------------
# 관    0.014292
# 위    0.008188
#      0.273432
# 회    0.016472
# 의    0.011548
#        ...
# 서    0.004294
# 통    0.004118
# 합    0.004123
# 변    0.004117
# 화    0.004116
# Length: 100, dtype: float64
#
#
# Keyword Significance Scores for "조태열 외교 “이번엔 中 시진핑 방한할 차례…합당한 순서”":
# -------------------------------------------------------------------
# 조    0.007840
# 태    0.003766
# 열    0.005778
#      0.275053
# 외    0.009639
#        ...
# 율    0.002832
# 갈    0.003016
# 등    0.003010
# 해    0.002798
# 강    0.002309
# Length: 137, dtype: float64
#
#
# Keyword Significance Scores for "한동훈, ‘차기 대통령 선호도’ 최고치…이재명 바짝 추격":
# ------------------------------------------------------------------
# 한    0.006760
# 동    0.008169
# 훈    0.004647
#      0.270129
# 국    0.009393
#        ...
# 페    0.002361
# 참    0.002189
# 하    0.002490
# 면    0.002737
# 된    0.002232
# Length: 149, dtype: float64
#
#
# Keyword Significance Scores for "민주, ‘국민참여 공천제’ 실시…“혁신과 통합이 원칙”":
# -----------------------------------------------------------------
# 임    0.003679
# 혁    0.008712
# 백    0.004019
#      0.269326
# 더    0.004894
#        ...
# 열    0.002198
# 쇠    0.002162
# 립    0.002196
# 투    0.002132
# 망    0.002026
# Length: 154, dtype: float64
#
#
# Keyword Significance Scores for "이낙연 “이준석과 함께 해야…세대통합 모델될 수 있어”":
# -----------------------------------------------------------------
# 이    0.013592
# 낙    0.003292
# 연    0.009359
#      0.269432
# 더    0.005087
#        ...
# 심    0.003883
# 점    0.002409
# 그    0.002538
# 때    0.002583
# 호    0.001876
# Length: 154, dtype: float64
#
#
# Keyword Significance Scores for "‘탈당’ 비명 3인, ‘미래대연합’ 창당 선언…박원석-정태근 동참":
# -----------------------------------------------------------------------
# 더    0.003009
# 불    0.006653
# 어    0.004423
# 민    0.014652
# 주    0.007866
#        ...
# 도    0.003570
# 덕    0.003533
# 복    0.003343
# 뢰    0.003308
# 봉    0.002243
# Length: 119, dtype: float64
#
#
# Keyword Significance Scores for "민주당 공관위장 “국민참여 공천 실시…증오-폭력발언 공천기준 반영”":
# ------------------------------------------------------------------------
# 공    0.038986
# 천    0.032925
#      0.280654
# 관    0.014241
# 리    0.008350
#        ...
# 요    0.004150
# 조    0.009735
# 건    0.004172
# 강    0.004172
# 혜    0.003320
# Length: 98, dtype: float64
#
#
# Keyword Significance Scores for "김정은→기시다 서한 뒤 日 비난 자제하는 北…대일정책 계산법에 주목":
# ------------------------------------------------------------------------
# 북    0.013850
# 한    0.014497
#      0.275795
# 노    0.008882
# 동    0.007433
#        ...
# 송    0.001618
# 폐    0.001481
# 포    0.001501
# 계    0.001553
# 메    0.001506
# Length: 195, dtype: float64
#
#
# Keyword Significance Scores for "尹대통령, 관료사회 ‘복지부동’에 답답…내각제까지 거론":
# -----------------------------------------------------------------
# 윤    0.003431
# 석    0.008036
# 열    0.005662
#      0.274067
# 대    0.023008
#        ...
# 락    0.002763
# 달    0.002650
# 라    0.004673
# 드    0.002630
# 브    0.002843
# Length: 131, dtype: float64
#
#
# Keyword Significance Scores for "홍문표, ‘윤심 공천’ 우려에 “한동훈 역할 중요…당무감사 공개해야”":
# -------------------------------------------------------------------------
# 이    0.007250
# 철    0.004693
# 규    0.005005
#      0.273644
# 공    0.014627
#        ...
# 희    0.003050
# 특    0.002499
# 검    0.002526
# 스    0.002540
# 크    0.002565
# Length: 148, dtype: float64
#
#
# Keyword Significance Scores for "법원 “尹 ‘바이든 vs 날리면’ 논란, MBC 정정보도하라”…외교부 승소":
# ----------------------------------------------------------------------------
# 항    0.002572
# 소    0.007708
#      0.274205
# 유    0.004883
# 튜    0.002314
#        ...
# 불    0.002036
# 견    0.002053
# 출    0.002027
# 변    0.002160
# 종    0.002109
# Length: 172, dtype: float64
#
#
# Keyword Significance Scores for "與, ‘이재명 특혜’ 겨냥 “지역 위급환자 서울 오지 않는 체계 구축할 것”":
# -----------------------------------------------------------------------------
# 지    0.012921
# 역    0.010127
#      0.284093
# 의    0.036352
# 대    0.016668
#        ...
# 죄    0.001394
# 직    0.001431
# 질    0.001431
# 찰    0.002131
# 쟁    0.001424
# Length: 195, dtype: float64
#
#
# Keyword Significance Scores for "이낙연, 지지자 ‘이재명 칼빵’ 막말 사과…민주 “반인륜적 망언”":
# -----------------------------------------------------------------------
# 일    0.003765
# 부    0.006407
#      0.272806
# 지    0.028544
# 자    0.012830
#        ...
# 막    0.002492
# 말    0.002434
# 염    0.002306
# 즉    0.002132
# 흥    0.002111
# Length: 169, dtype: float64
#
#
# Keyword Significance Scores for "이준석 개혁신당, 20일 공식 출범…중앙당 창당대회 개최":
# ------------------------------------------------------------------
# 이    0.013476
# 준    0.009708
# 석    0.005540
#      0.272232
# 개    0.015544
#        ...
# 과    0.004521
# 때    0.002892
# 문    0.002981
# 효    0.002918
# 율    0.002978
# Length: 129, dtype: float64
#
#
# Keyword Significance Scores for "류호정 “탈당은 없다…정의당 민주당 2중대 아닌 제3지대로”":
# --------------------------------------------------------------------
# 정    0.028233
# 의    0.040804
# 당    0.051104
#      0.279549
# 원    0.018909
#        ...
# 느    0.004885
# 낌    0.004999
# 얘    0.004774
# 라    0.005108
# 고    0.003932
# Length: 84, dtype: float64
#
#
# Keyword Significance Scores for "이재명 “민주주의 퇴행의 시대…문익환 목사 용기에서 답을 찾겠다”":
# -----------------------------------------------------------------------
# 흉    0.002893
# 기    0.013266
#      0.261057
# 피    0.004534
# 습    0.004501
#        ...
# 모    0.004808
# 란    0.004659
# 념    0.004374
# 제    0.004508
# 예    0.003932
# Length: 103, dtype: float64
#
#
# Keyword Significance Scores for "북한, 남파간첩 지령 ‘평양방송’ 중단…대남교류 단체도 정리":
# --------------------------------------------------------------------
# 북    0.013636
# 한    0.012977
#      0.269262
# 노    0.007176
# 동    0.011504
#        ...
# 면    0.002042
# 추    0.002278
# 측    0.002260
# 예    0.002347
# 슬    0.001937
# Length: 158, dtype: float64
#
#
# Keyword Significance Scores for "이상민 “국힘 중진, 신랄히 얘기…민주 중진들은 말 한마디 안 해”":
# ------------------------------------------------------------------------
# 중    0.008275
# 진    0.009124
#      0.275537
# 문    0.004614
# 제    0.008064
#        ...
# 차    0.002984
# 관    0.003028
# 출    0.004623
# 예    0.002787
# 본    0.002799
# Length: 135, dtype: float64
#
#
# Keyword Significance Scores for "“한반도 상황, 6·25 직전만큼 위험…김정은, 전쟁 나설 결심”":
# -----------------------------------------------------------------------
# 북    0.015523
# 한    0.018991
#      0.271134
# 노    0.013295
# 동    0.006848
#        ...
# 법    0.002703
# 확    0.002688
# 용    0.002654
# 사    0.002662
# 승    0.003703
# Length: 145, dtype: float64
#
#
# Keyword Significance Scores for "“이재명 일정에 맞추면 끝없어”…법원, 당분간 ‘李없는 李재판’ 진행키로[법조 Zoom In/대장동 재판 따라잡기]":
# ---------------------------------------------------------------------------------------------------
# 경    0.003781
# 기    0.009046
#      0.277106
# 성    0.004612
# 남    0.006070
#        ...
# 간    0.001907
# 파    0.002102
# 악    0.001323
# 여    0.001308
# 투    0.001263
# Length: 214, dtype: float64
#
#
# Keyword Significance Scores for "류호정 “탈당 안한다…정의당 ‘민주당 2중대’ 아닌 제3지대로 가야”":
# -------------------------------------------------------------------------
# 개    0.009627
# 인    0.009866
#      0.287890
# 활    0.017504
# 동    0.015880
#        ...
# 론    0.003763
# 청    0.004246
# 예    0.004078
# 목    0.004001
# 강    0.003586
# Length: 95, dtype: float64
#
#
# Keyword Significance Scores for "“北, 작년 中선박 33척 구매…전년 대비 5배 증가”":
# -----------------------------------------------------------------
# 자    0.005892
# 료    0.006459
#      0.281717
# 사    0.014284
# 진    0.004274
#        ...
# 동    0.006247
# 불    0.004160
# 법    0.004480
# 행    0.004277
# 심    0.002824
# Length: 97, dtype: float64
#
#
# Keyword Significance Scores for "장만채 前 전남도교육감 민주당 탈당 ‘이낙연 신당’ 합류하나":
# --------------------------------------------------------------------
# 이    0.024739
# 낙    0.007647
# 연    0.008140
#      0.262966
# 더    0.005108
#        ...
# 조    0.003513
# 응    0.003299
# 바    0.003231
# 람    0.003496
# 안    0.002386
# Length: 118, dtype: float64
#
#
# Keyword Significance Scores for "‘피습’ 회복 중 이재명 “민주주의 무너진 퇴행의 시대 문익환 용기 기억”":
# ----------------------------------------------------------------------------
# 흉    0.004795
# 기    0.017046
#      0.263940
# 피    0.008238
# 습    0.010499
#        ...
# 모    0.006594
# 추    0.003796
# 배    0.003697
# 념    0.003668
# 제    0.002623
# Length: 107, dtype: float64
#
#
# Keyword Significance Scores for "[단독]“北, 작년 러서 사치품 수백만달러 반입… 무기제공 대가인 듯”":
# --------------------------------------------------------------------------
# 무    0.004253
# 기    0.007079
#      0.262370
# 사    0.016187
# 치    0.010239
#        ...
# 협    0.002053
# 력    0.002024
# 측    0.001950
# 진    0.002094
# 규    0.001478
# Length: 168, dtype: float64
#
#
# Keyword Significance Scores for "野탈당 3인 ‘미래대연합’, 이낙연 ‘새로운 미래’… 합종연횡 본격화":
# -------------------------------------------------------------------------
# 신    0.010439
# 당    0.029288
#      0.269579
# 박    0.003604
# 원    0.015012
#        ...
# 결    0.001628
# 텐    0.001785
# 트    0.001866
# 필    0.001786
# 리    0.001180
# Length: 198, dtype: float64
#
#
# Keyword Significance Scores for "野공관위 “증오-폭력발언, 공천에 반영”":
# ---------------------------------------------------------
# 임    0.003440
# 혁    0.003817
# 백    0.004143
#      0.275151
# 위    0.015775
#        ...
# 도    0.002353
# 과    0.002445
# 안    0.002312
# 해    0.002370
# 윤    0.002453
# Length: 148, dtype: float64
#
#
# Keyword Significance Scores for "與 “1말2초 수도권 공천, 2말3초 영남… 승부처부터 마무리”":
# ----------------------------------------------------------------------
# 관    0.010874
# 위    0.017353
#      0.261691
# 회    0.008729
# 의    0.010253
#        ...
# 협    0.002311
# 절    0.002704
# 물    0.002749
# 안    0.005132
# 용    0.001776
# Length: 140, dtype: float64
#
#
# Keyword Significance Scores for "野 “이재명 피습 은폐 의혹 재수사해야”… 與 “음모론 여론몰이”":
# -----------------------------------------------------------------------
# 현    0.004699
# 장    0.009414
#      0.273654
# 청    0.008029
# 소    0.009818
#        ...
# 통    0.002508
# 상    0.002583
# 진    0.002624
# 화    0.003072
# 영    0.002529
# Length: 143, dtype: float64
#
#
# Keyword Significance Scores for "“北, 김정은 ‘대남기구 정리’ 지시따라 통일전선부 통폐합 수순”":
# -----------------------------------------------------------------------
# 선    0.006749
# 희    0.001821
#      0.272971
# 외    0.009030
# 무    0.009596
#        ...
# 페    0.002213
# 말    0.001379
# 련    0.001397
# 름    0.001580
# 길    0.001583
# Length: 190, dtype: float64
#
#
# Keyword Significance Scores for "위원장 셀프민원 공방속…  방심위, 야권위원 2명 해촉건의 ‘충돌’":
# ------------------------------------------------------------------------
# 비    0.005896
# 밀    0.002334
#      0.275728
# 유    0.010653
# 지    0.013576
#        ...
# 술    0.001898
# 족    0.001683
# 초    0.001704
# 단    0.001769
# 태    0.001694
# Length: 166, dtype: float64
#
#
# Keyword Significance Scores for "[주성하 기자의 서울과 평양사이]도발의 시간이 다가오고 있다":
# --------------------------------------------------------------------
# 김    0.013260
# 정    0.016958
# 은    0.007686
#      0.276893
# 새    0.002930
#        ...
# 불    0.001610
# 즉    0.001479
# 거    0.001403
# 향    0.001434
# 순    0.001421
# Length: 224, dtype: float64
#
#
# Keyword Significance Scores for "한미일, 北 탄도미사일 발사에 “도발할수록 3국 안보협력 강화”":
# ----------------------------------------------------------------------
# 우    0.002634
# 리    0.013022
# 나    0.003828
# 라    0.008752
#      0.272574
#        ...
# 예    0.003234
# 주    0.003155
# 개    0.003098
# 만    0.003375
# 큼    0.003332
# Length: 112, dtype: float64
#
#
# Keyword Significance Scores for "日 “北 탄도미사일 EEZ 밖 낙하…최소 500㎞ 비행”":
# ------------------------------------------------------------------
# 북    0.012262
# 한    0.016162
#      0.277005
# 지    0.008100
# 난    0.003398
#        ...
# 와    0.002880
# 다    0.002441
# 예    0.002378
# 태    0.002255
# 응    0.002404
# Length: 136, dtype: float64
#
#
# Keyword Significance Scores for "[단독]‘성희롱 논란’ 현근택 ‘3인 합의문’ 공개되자…당사자 “합의한 사실 없다”":
# ---------------------------------------------------------------------------------
# 민    0.008516
# 주    0.008500
#      0.279344
# 연    0.005947
# 구    0.006459
#        ...
# 착    0.003168
# 조    0.004474
# 온    0.003262
# 라    0.003245
# 채    0.002658
# Length: 117, dtype: float64
#
#
# Keyword Significance Scores for "‘성희롱 발언 논란’ 현근택, 피해자와 합의 중…“비난 멈춰달라”":
# -----------------------------------------------------------------------
# 변    0.002672
# 호    0.003275
# 사    0.019098
#      0.277256
# 성    0.010029
#        ...
# 명    0.004815
# 표    0.002970
# 류    0.002972
# 취    0.002946
# 방    0.002224
# Length: 116, dtype: float64
#
#
# Keyword Significance Scores for "개혁연합신당, 민주당에 ‘비례연합정당’ 제안…꼼수 위성정당 우려":
# ----------------------------------------------------------------------
# 야    0.005309
# 권    0.007901
#      0.275877
# 소    0.007698
# 수    0.004766
#        ...
# 차    0.002613
# 내    0.002319
# 향    0.002647
# 외    0.002553
# 규    0.002006
# Length: 129, dtype: float64
#
#
# Keyword Significance Scores for "당정 “취약계층 전기료 동결-소상공인 대출이자 경감”…野 “총선용 선심대책”":
# -----------------------------------------------------------------------------
# 보    0.003476
# 기    0.015325
#      0.273589
# 한    0.006454
# 덕    0.002294
#        ...
# 운    0.001707
# 데    0.001722
# 침    0.001881
# 김    0.002400
# 일    0.001633
# Length: 195, dtype: float64
#
#
# Keyword Significance Scores for "민주, 총리실 ‘1㎝ 열상’ 문자에 “테러사건 축소 왜곡”…고발 예고":
# -------------------------------------------------------------------------
# 이    0.007032
# 재    0.003131
# 명    0.006873
#      0.275283
# 더    0.003595
#        ...
# 목    0.002111
# 비    0.002196
# 채    0.002386
# 연    0.002350
# 성    0.001891
# Length: 156, dtype: float64
#
#
# ...
# 율    0.002192
# 행    0.002037
# 삶    0.001786
# 향    0.001932
# Length: 179, dtype: float64
#
#
# Keyword Significance Scores for "‘명룡대전’ 시작…與 “이재명, 도망가면 비겁” 野 “원희룡이 돌덩이”":
# --------------------------------------------------------------------------
# 이    0.017584
# 재    0.003038
# 명    0.004947
#      0.269040
# 민    0.016787
#        ...
# 얘    0.002130
# 먹    0.002921
# 질    0.002514
# 느    0.002579
# 낌    0.002350
# Length: 151, dtype: float64
#
#
# Keyword Significance Scores for "‘민주당 돈봉투 의혹’ 송영길 재판 내달 2일 시작":
# ---------------------------------------------------------------
# 더    0.003030
# 불    0.004623
# 어    0.003666
# 민    0.009239
# 주    0.008976
#        ...
# 남    0.002145
# 야    0.002358
# 권    0.002364
# 변    0.002390
# 호    0.001950
# Length: 152, dtype: float64
#
#
# Keyword Significance Scores for "한동훈, 이재명 ‘칼로 죽이려 해’에 “그 정도면 망상…누가 죽인단 건가”":
# ----------------------------------------------------------------------------
# 사    0.007539
# 람    0.008351
#      0.282184
# 범    0.009018
# 죄    0.008693
#        ...
# 확    0.005939
# 신    0.005787
# 안    0.005430
# 음    0.005185
# 적    0.003483
# Length: 85, dtype: float64
#
#
# Keyword Significance Scores for "도발 엄두도 못 내게… 항모까지 동원한 한미일 합동훈련[원대연의 잡학사진]":
# ----------------------------------------------------------------------------
# 북    0.004159
# 한    0.010584
#      0.262618
# 김    0.005049
# 정    0.003065
#        ...
# 임    0.002222
# 무    0.002346
# 요    0.002195
# 경    0.002139
# 례    0.002083
# Length: 150, dtype: float64
#
#
# Keyword Significance Scores for "새로운선택, ‘제3지대 통합’ 실무협의기구 제안…“단일정당 만들어야”":
# -------------------------------------------------------------------------
# 지    0.013635
# 대    0.024247
#      0.284376
# 연    0.008603
# 형    0.005729
#        ...
# 자    0.002261
# 칙    0.001872
# 역    0.001848
# 례    0.001902
# 고    0.001900
# Length: 164, dtype: float64
#
#
# Keyword Significance Scores for "[단독]‘창원·제주·민노총 간첩단’ 하부망만 70명 넘는데…경찰 수사인력은 20명도 안돼":
# ------------------------------------------------------------------------------------
# 국    0.021311
# 가    0.006429
#      0.286069
# 정    0.018675
# 보    0.013263
#        ...
# 예    0.005052
# 절    0.002678
# 후    0.002619
# 망    0.003021
# 도    0.002664
# Length: 119, dtype: float64
#
#
# Keyword Significance Scores for "국회 15일 만에 복귀한 이재명 대표 “결코 죽지 않는다” [청계천 옆 사진관]":
# -------------------------------------------------------------------------------
# 이    0.019609
# 재    0.015392
# 명    0.009441
#      0.267298
# 더    0.009100
#        ...
# 죽    0.002888
# 준    0.002822
# 비    0.003022
# 돌    0.003032
# 입    0.002877
# Length: 141, dtype: float64
#
#
# Keyword Significance Scores for "한동훈 “재건축 규제 완화가 포퓰리즘이냐”…尹대통령 첫 언급":
# --------------------------------------------------------------------
# 한    0.006215
# 동    0.009172
# 훈    0.005041
#      0.264041
# 국    0.018651
#        ...
# 김    0.002404
# 출    0.002351
# 현    0.002395
# 청    0.002661
# 래    0.002639
# Length: 140, dtype: float64
#
#
# Keyword Significance Scores for "통일차관 “탈북민, 한국 주도 통일 위해 중요…고위층 탈북 늘어”":
# -----------------------------------------------------------------------
# 승    0.002753
# 현    0.003425
#      0.276824
# 통    0.022244
# 일    0.015562
#        ...
# 보    0.003785
# 니    0.003570
# 상    0.003193
# 용    0.003126
# 언    0.003130
# Length: 115, dtype: float64
#
#
# Keyword Significance Scores for "‘친낙계’ 박시종 전 선임행정관도 민주당 탈당…“이낙연 신당 합류”":
# ------------------------------------------------------------------------
# 시    0.011079
# 종    0.006308
#      0.263421
# 청    0.007139
# 와    0.006937
#        ...
# 진    0.004064
# 상    0.004413
# 황    0.004448
# 방    0.004517
# 침    0.004398
# Length: 99, dtype: float64
#
#
# Keyword Significance Scores for "한동훈 “서울서 통쾌하고 놀랄만한 선거 하겠다”":
# -------------------------------------------------------------
# 한    0.003908
# 동    0.012129
# 훈    0.005773
#      0.264538
# 국    0.022770
#        ...
# 마    0.004996
# 봄    0.004783
# 승    0.005001
# 리    0.008318
# 후    0.003378
# Length: 86, dtype: float64
#
#
# Keyword Significance Scores for "“다선이 죄는 아니잖나”…국힘, 영남 다선 겨냥 공천룰에 부글":
# ---------------------------------------------------------------------
# 한    0.006625
# 동    0.008676
# 훈    0.003707
#      0.278040
# 국    0.005624
#        ...
# 않    0.001952
# 는    0.002117
# 손    0.001981
# 간    0.002005
# 담    0.001940
# Length: 183, dtype: float64
#
#
# Keyword Significance Scores for "오세훈 “올해 혁신적인 대중교통 변신 있을 것…메가시티, 총선 이후”":
# -------------------------------------------------------------------------
# 오    0.004317
# 세    0.002838
# 훈    0.002207
#      0.276273
# 서    0.016259
#        ...
# 외    0.001391
# 군    0.001396
# 활    0.002133
# 심    0.001566
# 예    0.001555
# Length: 207, dtype: float64
#
#
# Keyword Significance Scores for "이준석 “이낙연과 연대, 현실론 넘는 파격 있다면 가능”":
# ------------------------------------------------------------------
# 이    0.015541
# 준    0.009159
# 석    0.007600
#      0.266206
# 개    0.009985
#        ...
# 내    0.003486
# 부    0.005694
# 견    0.003907
# 최    0.004750
# 호    0.003102
# Length: 113, dtype: float64
#
#
# Keyword Significance Scores for "“민주당 적격심사, 범죄자도 되는데 난 왜”…안희정 전 비서 ‘발끈’":
# -------------------------------------------------------------------------
# 안    0.005974
# 희    0.006544
# 정    0.010574
#      0.275633
# 충    0.006833
#        ...
# 생    0.004425
# 각    0.004665
# 결    0.004508
# 말    0.004443
# 씀    0.004360
# Length: 94, dtype: float64
#
#
# Keyword Significance Scores for "이준석 신당에 ‘이재명 저격수’ 남윤중 변호사 합류…국힘 출신":
# ---------------------------------------------------------------------
# 이    0.008438
# 준    0.004421
# 석    0.005179
#      0.262791
# 개    0.013443
#        ...
# 감    0.002886
# 경    0.003110
# 험    0.003290
# 바    0.003278
# 탕    0.003038
# Length: 138, dtype: float64
#
#
# Keyword Significance Scores for "민주, 쌍특검법·이태원특별법 수용 촉구 “국민의 명령”":
# -----------------------------------------------------------------
# 김    0.005653
# 건    0.006790
# 희    0.007424
#      0.268921
# 여    0.011627
#        ...
# 소    0.002428
# 방    0.002418
# 졸    0.002224
# 라    0.002236
# 판    0.001777
# Length: 141, dtype: float64
#
#
# Keyword Significance Scores for "국민의힘, 총선 최대 격전지로 대전 꼽아 ‘혁신공천’ 주목":
# -------------------------------------------------------------------
# 영    0.004356
# 화    0.003081
#      0.277094
# 국    0.019767
# 민    0.021651
#        ...
# 김    0.002387
# 광    0.002402
# 직    0.002081
# 법    0.002127
# 무    0.002198
# Length: 158, dtype: float64
#
#
# Keyword Significance Scores for "尹 “세제개혁, 과감하게 해달라…ISA가입 대상·비과세 한도 확대”":
# ------------------------------------------------------------------------
# 윤    0.003156
# 석    0.006020
# 열    0.003698
#      0.272196
# 대    0.019946
#        ...
# 플    0.002926
# 랫    0.002847
# 폼    0.002979
# 택    0.003449
# 헌    0.001600
# Length: 148, dtype: float64
#
#
# Keyword Significance Scores for "“대만은 중국의 대만”…北, 친미 라이칭더 당선에 ‘하나의 중국’ 지지":
# --------------------------------------------------------------------------
# 북    0.002481
# 한    0.005116
#      0.282752
# 지    0.015703
# 난    0.003236
#        ...
# 필    0.003456
# 연    0.003416
# 진    0.006574
# 법    0.003101
# 위    0.002290
# Length: 103, dtype: float64
#
#
# Keyword Significance Scores for "尹 “공매도 금지, 총선용 아냐…ISA납입 대상·비과세 한도 확대”":
# ------------------------------------------------------------------------
# 윤    0.002935
# 석    0.004584
# 열    0.003521
#      0.272455
# 대    0.021083
#        ...
# 신    0.003133
# 앞    0.002668
# 으    0.002601
# 로    0.002592
# 혜    0.001917
# Length: 158, dtype: float64
#
#
# Keyword Significance Scores for "한동훈, 정청래 지역구 마포을에 김경율 ‘자객공천’":
# ---------------------------------------------------------------
# 한    0.005320
# 동    0.009219
# 훈    0.005998
#      0.267172
# 국    0.013330
#        ...
# 도    0.002794
# 격    0.002910
# 속    0.002827
# 음    0.002759
# 라    0.003023
# Length: 116, dtype: float64
#
#
# Keyword Significance Scores for "정부, 반려동물 산업 거점 ‘원-웰페어 밸리’ 조성…400억 규모":
# -----------------------------------------------------------------------
# 식    0.012631
# 품    0.019329
#      0.286137
# 공    0.007713
# 모    0.012373
#        ...
# 향    0.003749
# 후    0.003756
# 차    0.003807
# 질    0.004092
# 만    0.003943
# Length: 103, dtype: float64
#
#
# Keyword Significance Scores for "尹대통령 “증권시장, 국민·기업 함께 성장하는 상생의 장”":
# -------------------------------------------------------------------
# 윤    0.007569
# 석    0.008065
# 열    0.008837
#      0.265969
# 대    0.023018
#        ...
# 미    0.005102
# 벤    0.007588
# 치    0.009164
# 마    0.008107
# 킹    0.006169
# Length: 78, dtype: float64
#
#
# Keyword Significance Scores for "‘김정은 시정연설’ 반향 전하며 ‘철저한 과업 관철’ 독려":
# -------------------------------------------------------------------
# 북    0.005658
# 한    0.007216
#      0.272127
# 노    0.008298
# 동    0.012058
#        ...
# 약    0.002284
# 토    0.002584
# 협    0.002692
# 력    0.002498
# 난    0.001672
# Length: 151, dtype: float64
#
#
# Keyword Significance Scores for "이재명 “이낙연·비명3인 탈당 안타까워…단일대오로 새 길 개척해야”":
# ------------------------------------------------------------------------
# 이    0.027320
# 재    0.015738
# 명    0.020622
#      0.264237
# 더    0.009353
#        ...
# 척    0.006276
# 책    0.006318
# 임    0.006246
# 소    0.005861
# 결    0.005626
# Length: 80, dtype: float64
#
#
# Keyword Significance Scores for "당무복귀 이재명 “법·펜으로 안되니 칼로 죽이려…결코 죽지 않는다”":
# ------------------------------------------------------------------------
# 피    0.003629
# 습    0.003925
#      0.279666
# 보    0.004215
# 름    0.003076
#        ...
# 실    0.002230
# 질    0.002136
# 마    0.002006
# 비    0.002069
# 김    0.002349
# Length: 162, dtype: float64
#
#
# Keyword Significance Scores for "尹 “ISA 계좌 납입·비과세 한도, 두 배 이상 늘리겠다”":
# --------------------------------------------------------------------
# 상    0.015121
# 생    0.005136
#      0.271669
# 금    0.013330
# 융    0.011368
#        ...
# 동    0.001572
# 무    0.001457
# 섭    0.001407
# 태    0.001399
# 수    0.002050
# Length: 197, dtype: float64
#
#
# Keyword Significance Scores for "尹 “ISA 비과세 한도, 가입 대상 대폭 확대”":
# --------------------------------------------------------------
# 윤    0.003513
# 석    0.004328
# 열    0.005018
#      0.268339
# 대    0.022437
#        ...
# 비    0.003459
# 선    0.003545
# 공    0.003497
# 조    0.003447
# 봉    0.002366
# Length: 123, dtype: float64
#
#
# Keyword Significance Scores for "전치 6주 폭행 50대男…알고보니 지난 총선 민주당 예비후보":
# --------------------------------------------------------------------
# 배    0.019693
# 달    0.019856
#      0.267143
# 기    0.017761
# 사    0.028483
#        ...
# 근    0.004337
# 병    0.004338
# 송    0.004000
# 진    0.004353
# 단    0.004367
# Length: 93, dtype: float64
#
#
# Keyword Significance Scores for "이준석 “65세 이상 지하철 무임승차제 폐지” vs 대한노인회 “패륜아 정당”":
# ------------------------------------------------------------------------------
# 이    0.009350
# 준    0.004327
# 석    0.004952
#      0.263662
# 개    0.004787
#        ...
# 보    0.002342
# 편    0.002611
# 앞    0.002751
# 으    0.002522
# 예    0.001583
# Length: 154, dtype: float64
#
#
# Keyword Significance Scores for "한동훈, ‘김여사 명품백 논란’에 “국민 걱정할 부분 있다” 첫 우려 표명":
# ----------------------------------------------------------------------------
# 국    0.009200
# 민    0.010240
#      0.270593
# 한    0.002818
# 동    0.002806
#        ...
# 편    0.002560
# 권    0.002463
# 형    0.002458
# 헌    0.002307
# 승    0.002025
# Length: 151, dtype: float64
#
#
# Keyword Significance Scores for "대통령실, 경호원에 끌려나간 강성희에 “금도 넘어선 일…위해 행위”":
# ------------------------------------------------------------------------
# 전    0.025584
# 북    0.013783
#      0.252809
# 주    0.008164
# 한    0.006145
#        ...
# 합    0.002749
# 가    0.002723
# 칭    0.002461
# 응    0.002311
# 예    0.001927
# Length: 135, dtype: float64
#
#
# Keyword Significance Scores for "與 “아빠도 1개월 출산휴가” 野 “2자녀땐 24평 공공임대”":
# ---------------------------------------------------------------------
# 여    0.008801
# 야    0.006576
#      0.271594
# 저    0.006682
# 출    0.016103
#        ...
# 김    0.002853
# 준    0.002775
# 일    0.003051
# 안    0.002932
# 규    0.002265
# Length: 159, dtype: float64
#
#
# Keyword Significance Scores for "이재명 “계양을 그대로 출마…총선 승리, 원내 1당·151석 목표”":
# ------------------------------------------------------------------------
# 이    0.022748
# 재    0.006909
# 명    0.007762
#      0.267624
# 더    0.008116
#        ...
# 잘    0.005221
# 못    0.004992
# 유    0.004666
# 정    0.008181
# 예    0.003831
# Length: 93, dtype: float64
#
#
# Keyword Significance Scores for "김용남 “공천 관련 일방 손 들어주는 한동훈, 여의도 문법 배워야”[중립기어 라이브]":
# ----------------------------------------------------------------------------------
# 국    0.006220
# 민    0.005146
#      0.271428
# 탈    0.002185
# 당    0.011305
#        ...
# 브    0.002280
# 차    0.001310
# 유    0.001473
# 튜    0.001484
# 채    0.001233
# Length: 222, dtype: float64
#
#
# Keyword Significance Scores for "中 신화통신 “北, 한국 총선 의식해 ‘제1 적대국’ 규정”":
# --------------------------------------------------------------------
# 정    0.041179
# 부    0.006415
#      0.271881
# 대    0.024056
# 미    0.012587
#        ...
# 개    0.003438
# 다    0.004148
# 음    0.004165
# 번    0.004245
# 심    0.003402
# Length: 104, dtype: float64
#
#
# Keyword Significance Scores for "류호정 “‘비례연합정당’ 민주당 주도 아니라는 건 손바닥으로 하늘 가리는 소리”[중립기어 라이브]":
# -----------------------------------------------------------------------------------------
# 선    0.007036
# 택    0.001425
#      0.277275
# 참    0.001272
# 여    0.002548
#        ...
# 목    0.000721
# 췌    0.000752
# 브    0.001160
# 튜    0.000811
# 채    0.000794
# Length: 296, dtype: float64
#
#
# Keyword Significance Scores for "‘尹대통령 친구’ 석동현, 김웅 불출마 송파갑에 출사표":
# -----------------------------------------------------------------
# 석    0.007185
# 동    0.011173
# 현    0.005347
#      0.269208
# 민    0.020617
#        ...
# 전    0.006064
# 가    0.003583
# 활    0.005211
# 우    0.003196
# 별    0.003352
# Length: 113, dtype: float64
#
#
# Keyword Significance Scores for "‘빨간 조끼·빨간 장갑’ 한동훈 “1호 공약 배달왔어요”":
# ------------------------------------------------------------------
# 한    0.005777
# 동    0.013115
# 훈    0.004949
#      0.273481
# 국    0.011009
#        ...
# 편    0.002001
# 필    0.002019
# 예    0.002035
# 액    0.002051
# 량    0.001450
# Length: 157, dtype: float64
#
#
# Keyword Significance Scores for "여당, ‘강성희 끌어내기’ 논란에 “강, 몰상식 행위 석고대죄해야”":
# ------------------------------------------------------------------------
# 강    0.007296
# 성    0.007957
# 희    0.008212
#      0.270245
# 경    0.011718
#        ...
# 승    0.003992
# 황    0.003966
# 생    0.003838
# 면    0.003722
# 리    0.003738
# Length: 91, dtype: float64
#
#
# Keyword Significance Scores for "與 ‘중진 물갈이’ 공천룰 예외 적용…권성동·윤상현·김태호 빠지나":
# -----------------------------------------------------------------------
# 영    0.002262
# 화    0.005040
#      0.274302
# 국    0.006900
# 민    0.004669
#        ...
# 야    0.002927
# 다    0.004974
# 음    0.004755
# 례    0.002869
# 련    0.002981
# Length: 121, dtype: float64
#
#
# Keyword Significance Scores for "‘류희림 셀프 민원’ 의혹 고발했다고…경찰, 민주당도 조사한다":
# ---------------------------------------------------------------------
# 민    0.022967
# 주    0.010675
# 언    0.006829
# 론    0.006765
# 시    0.006654
#        ...
# 범    0.004211
# 죄    0.004135
# 무    0.003823
# 압    0.004027
# 색    0.002770
# Length: 101, dtype: float64
#
#
# Keyword Significance Scores for "김여사 명품백 의혹…한동훈 “아쉬운 점과 국민 걱정할 부분 있다”":
# -----------------------------------------------------------------------
# 한    0.003575
# 동    0.007314
# 훈    0.004060
#      0.270364
# 국    0.015436
#        ...
# 호    0.002337
# 행    0.002265
# 소    0.002352
# 용    0.002463
# 릴    0.002403
# Length: 152, dtype: float64
#
#
# Keyword Significance Scores for "탈북민 영화감독 “한류 접한 北 젊은층 주애 4대 세습 불만”":
# ---------------------------------------------------------------------
# 서    0.021548
# 울    0.004365
#      0.262354
# 초    0.005018
# 구    0.005028
#        ...
# 련    0.003328
# 무    0.003201
# 음    0.005023
# 의    0.003311
# 료    0.003328
# Length: 120, dtype: float64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 68
#      65     result = apply_text_tank(documents, "4월 10일 투표")
#      67 if __name__ == "__main__":
# ---> 68     main()
#
# Cell In[4], line 65, in main()
#      63 file_path = 'datasets/preprocessed.csv'
#      64 documents = load_documents(file_path)
# ---> 65 result = apply_text_tank(documents, "4월 10일 투표")
#
# Cell In[4], line 43, in apply_text_tank(documents, title)
#      41 for doc in documents:
#      42     document = doc['article']
# ---> 43     keyword_scores = textrank(document)
#      45     print()
#      46     header = "Keyword Significance Scores for \"%s\":" % doc['title']
#
# Cell In[4], line 29, in textrank(document, window_size, rsp)
#      27         if other_index >= 0 and other_index < len(words) and other_index != index:
#      28             other_word = words[other_index]
# ---> 29             edge_weights[word][other_word] += 1.0
#      31 # Apply PageRank to the weighted graph:
#      32 word_probabilities = pagerank.power_iteration(edge_weights, rsp=rsp)
#
# KeyboardInterrupt:

# %%
file_path = 'datasets/preprocessed.csv'
documents = load_documents(file_path)
apply_text_tank(documents, "총선")
# Out:
# Applying TextRank to "총선" ...
#
# Keyword Significance Scores for "조태열-블링컨 첫 통화…“한미 동맹 더욱 심화·발전”":
# ----------------------------------------------------------------
# 취    0.005755
# 임    0.010792
#      0.281809
# 인    0.008279
# 사    0.016701
#        ...
# 응    0.003055
# 보    0.004990
# 결    0.003145
# 행    0.003420
# 견    0.002889
# Length: 124, dtype: float64
#
#
# Keyword Significance Scores for "조국 “민주, 총선서 포용력 발휘해 반윤연대 꾸려야”":
# ----------------------------------------------------------------
# 정    0.026972
# 책    0.008983
#      0.274561
# 싱    0.003169
# 크    0.005612
#        ...
# 여    0.002074
# 달    0.002061
# 식    0.002080
# 범    0.003255
# 예    0.001972
# Length: 172, dtype: float64
#
#
# Keyword Significance Scores for "‘재산신고 누락’ 이균용 전 대법원장 후보자 경고 처분":
# -----------------------------------------------------------------
# 상    0.007658
# 장    0.028676
#      0.268016
# 주    0.010837
# 식    0.011314
#        ...
# 통    0.004234
# 일    0.004541
# 간    0.004393
# 백    0.004523
# 기    0.003674
# Length: 88, dtype: float64
#
#
# Keyword Significance Scores for "민주 윤리감찰단, ‘성희롱 발언 논란’ 현근택 대면 조사":
# ------------------------------------------------------------------
# 피    0.005679
# 해    0.014371
# 자    0.018483
#      0.275220
# 출    0.011442
#        ...
# 락    0.006838
# 명    0.007160
# 재    0.004315
# 표    0.004227
# 산    0.004338
# Length: 90, dtype: float64
#
#
# Keyword Significance Scores for "대통령실 “가장 중요한건 물가 안정…의료·주거 생계비 줄일 것”":
# ----------------------------------------------------------------------
# 성    0.009673
# 태    0.005957
#      0.270845
# 신    0.006197
# 임    0.009792
#        ...
# 상    0.002981
# 황    0.002803
# 검    0.002586
# 치    0.002741
# 속    0.001873
# Length: 150, dtype: float64
#
#
# Keyword Significance Scores for "“이태원 참사 특별법, 총선용 악용법”…尹, 거부권 행사 가능성":
# ----------------------------------------------------------------------
# 보    0.005623
# 기    0.004641
#      0.267747
# 윤    0.002415
# 석    0.002338
#        ...
# 후    0.002174
# 가    0.002098
# 촉    0.002144
# 김    0.002536
# 은    0.002103
# Length: 158, dtype: float64
#
#
# Keyword Significance Scores for "법원, 대통령실 특활비·수의계약 공개 판결…“국익침해 우려 없다”":
# -----------------------------------------------------------------------
# 뉴    0.007228
# 스    0.007335
# 타    0.007597
# 파    0.007722
#      0.274147
#        ...
# 함    0.002431
# 머    0.002358
# 침    0.002398
# 불    0.002449
# 복    0.002456
# Length: 130, dtype: float64
#
#
# Keyword Significance Scores for "이재명, 예비후보자 심사 통과…‘1심 실형’ 황운하·‘뇌물 기소’ 노웅래도":
# ----------------------------------------------------------------------------
# 이    0.010434
# 재    0.008474
# 명    0.006084
#      0.251493
# 더    0.004610
#        ...
# 군    0.002674
# 리    0.002771
# 예    0.002766
# 등    0.002891
# 록    0.002857
# Length: 134, dtype: float64
#
#
# Keyword Significance Scores for "돛 올린 우주항공청 “5월 말 개청 목표… 올해 약 8000억 원 투입 예정”":
# ------------------------------------------------------------------------------
# 보    0.007521
# 기    0.020317
#      0.272599
# 이    0.011534
# 종    0.003242
#        ...
# 달    0.001693
# 강    0.001617
# 도    0.001901
# 약    0.002091
# 최    0.001950
# Length: 164, dtype: float64
#
#
# Keyword Significance Scores for "‘코인 논란’ 김남국에 2차 강제조정…법원 “유감 표시하고 재발 방지를”":
# ---------------------------------------------------------------------------
# 남    0.008951
# 국    0.013331
#      0.274587
# 무    0.007403
# 소    0.011348
#        ...
# 려    0.003694
# 월    0.003593
# 급    0.003782
# 압    0.003852
# 류    0.003923
# Length: 106, dtype: float64
#
#
# Keyword Significance Scores for "민주 강성지지층 “왕수박 나갔다, 이제 잔수박 정리”":
# ----------------------------------------------------------------
# 더    0.002696
# 불    0.005810
# 어    0.003896
# 민    0.026849
# 주    0.018238
#        ...
# 도    0.003349
# 타    0.003407
# 생    0.003254
# 경    0.003316
# 복    0.003078
# Length: 129, dtype: float64
#
#
# Keyword Significance Scores for "탈당 기자회견서 결연한 모습 보인 이낙연[청계천 옆 사진관]":
# --------------------------------------------------------------------
# 보    0.001750
# 기    0.014528
#      0.265857
# 이    0.012278
# 낙    0.005054
#        ...
# 경    0.002617
# 호    0.002705
# 량    0.004048
# 탑    0.002768
# 승    0.002665
# Length: 130, dtype: float64
#
#
# Keyword Significance Scores for "‘한동훈 영입 1호’ 박상수 “악의적인 것은 책임 물어야…허위 날조 대응할 것”[중립기어 라이브]":
# -----------------------------------------------------------------------------------------
# 한    0.003030
# 동    0.008208
# 훈    0.001002
#      0.271114
# 대    0.006459
#        ...
# 콘    0.000953
# 텐    0.000944
# 츠    0.000969
# 램    0.000648
# 차    0.000651
# Length: 334, dtype: float64
#
#
# Keyword Significance Scores for "5·18조사위 “‘5월 광주’ 발포 책임자 전두환 확인…입증자료 부족”":
# --------------------------------------------------------------------------
# 민    0.003941
# 주    0.010928
# 화    0.003472
#      0.271687
# 운    0.003421
#        ...
# 파    0.001463
# 향    0.001456
# 편    0.001521
# 범    0.001429
# 례    0.001504
# Length: 195, dtype: float64
#
#
# Keyword Significance Scores for "이준석, 이재명 피습 특검에 “민주당, ‘특검 남발’ 문제의식 가져야”":
# --------------------------------------------------------------------------
# 수    0.017861
# 사    0.038937
#      0.261666
# 실    0.006898
# 관    0.009501
#        ...
# 글    0.004272
# 홍    0.004752
# 익    0.004604
# 내    0.004290
# 국    0.006557
# Length: 90, dtype: float64
#
#
# Keyword Significance Scores for "민주 검증위, ‘1심 의원직 상실형’ 황운하에 적격…노웅래도 통과":
# -----------------------------------------------------------------------
# 의    0.023744
# 원    0.024439
#      0.269808
# 청    0.007893
# 와    0.007702
#        ...
# 염    0.002879
# 태    0.002650
# 영    0.002667
# 경    0.001990
# 무    0.002029
# Length: 151, dtype: float64
#
#
# Keyword Significance Scores for "與공관위, 10명중 4명이 법조인 출신…당내선 중립성 우려 지적도":
# -----------------------------------------------------------------------
# 총    0.006823
# 선    0.006394
#      0.265100
# 공    0.017326
# 천    0.006161
#        ...
# 생    0.002264
# 각    0.002202
# 점    0.002354
# 김    0.002716
# 준    0.002176
# Length: 156, dtype: float64
#
#
# Keyword Significance Scores for "“업적들 무너뜨릴 것”“정계 은퇴하라”… 민주, 이낙연 탈당에 날선 ‘비난’":
# -----------------------------------------------------------------------------
# 보    0.003510
# 기    0.010313
#      0.267669
# 이    0.021884
# 낙    0.007200
#        ...
# 실    0.002750
# 반    0.002699
# 황    0.002853
# 과    0.002903
# 휘    0.002424
# Length: 122, dtype: float64
#
#
# Keyword Significance Scores for "조태용 “대공수사권, 국정원으로 복원돼야”…엑손모빌 의혹엔 “만난적 없어”":
# ----------------------------------------------------------------------------
# 보    0.022830
# 기    0.008248
#      0.262993
# 조    0.008611
# 태    0.005859
#        ...
# 라    0.002846
# 윤    0.002618
# 열    0.002609
# 요    0.002321
# 비    0.002347
# Length: 143, dtype: float64
#
#
# Keyword Significance Scores for "尹대통령 “자유시장 경제, 국민 모두 다 잘살게 되는 시스템”":
# ---------------------------------------------------------------------
# 윤    0.003631
# 석    0.006679
# 열    0.004297
#      0.274176
# 대    0.018621
#        ...
# 최    0.002490
# 총    0.002715
# 리    0.002796
# 획    0.002505
# 참    0.002348
# Length: 129, dtype: float64
#
#
# Keyword Significance Scores for "민주, 현역의원 평가 마무리…컷오프 대상 하위 20% 통보설에 당 ‘술렁’":
# ----------------------------------------------------------------------------
# 보    0.013799
# 기    0.006907
#      0.275512
# 이    0.008848
# 재    0.002497
#        ...
# 조    0.002516
# 면    0.002737
# 접    0.002735
# 규    0.002773
# 영    0.002257
# Length: 139, dtype: float64
#
#
# Keyword Significance Scores for "서울 정신병원서 사망자 명의로 마약류 처방하다 덜미":
# ---------------------------------------------------------------
# 서    0.010556
# 울    0.010712
# 시    0.013581
#      0.266856
# 강    0.011800
#        ...
# 조    0.003434
# 후    0.003795
# 유    0.003647
# 재    0.003380
# 통    0.003025
# Length: 106, dtype: float64
#
#
# Keyword Significance Scores for "붉은 넥타이 이낙연 “민주당 본래 가치 찾겠다”…지지자 “힘내세요”":
# ------------------------------------------------------------------------
# 이    0.020213
# 낙    0.004249
# 연    0.006849
#      0.265407
# 더    0.005102
#        ...
# 증    0.002982
# 행    0.003120
# 달    0.003043
# 내    0.003116
# 세    0.003288
# Length: 119, dtype: float64
#
#
# Keyword Significance Scores for "운동후 청사서 야근비 신청?…감사원, 부당 수령한 공무원 198명 적발":
# --------------------------------------------------------------------------
# 보    0.004770
# 기    0.009805
#      0.265467
# 서    0.016078
# 울    0.013575
#        ...
# 권    0.003952
# 숙    0.003877
# 경    0.003517
# 도    0.003560
# 예    0.002876
# Length: 110, dtype: float64
#
#
# Keyword Significance Scores for "이낙연 “양당 독점구도 깨는 의석수 필요…지역구 전부 출마”[일문일답]":
# --------------------------------------------------------------------------
# 이    0.009480
# 낙    0.001611
# 연    0.005430
#      0.274137
# 더    0.001147
#        ...
# 타    0.001062
# 파    0.001104
# 폐    0.000946
# 것    0.001010
# 험    0.000964
# Length: 265, dtype: float64
#
#
# Keyword Significance Scores for "천하람 “개혁신당 12일 인재 영입 발표…아주 좋은 분”[중립기어 라이브]":
# ----------------------------------------------------------------------------
# 개    0.003508
# 혁    0.002309
# 신    0.004530
# 당    0.006677
#      0.274964
#        ...
# 콘    0.000861
# 텐    0.000851
# 츠    0.000856
# 램    0.000592
# 췌    0.000566
# Length: 371, dtype: float64
#
#
# Keyword Significance Scores for "中은 조용한데 러시아는 “왕이와 한반도 문제 논의”…온도 차이 이유는?":
# --------------------------------------------------------------------------
# 중    0.020305
# 국    0.025937
#      0.269041
# 러    0.012258
# 시    0.014247
#        ...
# 검    0.001870
# 토    0.001899
# 강    0.001716
# 각    0.002687
# 소    0.001530
# Length: 174, dtype: float64
#
#
# Keyword Significance Scores for "5월 개청 우주항공청…2045년 화성 탐사 도전 선언한 한국형 나사 ‘KASA’":
# -------------------------------------------------------------------------------
# 이    0.009710
# 종    0.006050
# 호    0.006273
#      0.277905
# 과    0.008111
#        ...
# 망    0.002184
# 쟁    0.002085
# 세    0.002087
# 래    0.002039
# 척    0.002036
# Length: 160, dtype: float64
#
#
# Keyword Significance Scores for "정부, 유엔 ‘中인권검토’ 앞두고 첫 서면질의…北 강제북송 적시":
# ----------------------------------------------------------------------
# 시    0.009240
# 민    0.013849
# 사    0.015757
# 회    0.009275
#      0.273311
#        ...
# 리    0.003012
# 핑    0.003018
# 련    0.002339
# 무    0.002245
# 위    0.002406
# Length: 131, dtype: float64
#
#
# Keyword Significance Scores for "이낙연 신당 구상…‘타협의 다당제·분권형 대통령제’ 제시":
# ------------------------------------------------------------------
# 이    0.007399
# 낙    0.004247
# 연    0.006667
#      0.272739
# 더    0.006553
#        ...
# 단    0.002853
# 체    0.002973
# 해    0.003163
# 말    0.003323
# 씀    0.003120
# Length: 130, dtype: float64
#
#
# Keyword Significance Scores for "노영민 文청와대 비서실장, 청주 상당 출사표…“정권 심판”":
# -------------------------------------------------------------------
# 이    0.010689
# 낙    0.002452
# 연    0.006500
#      0.271864
# 탈    0.004311
#        ...
# 야    0.001948
# 양    0.001906
# 인    0.001798
# 빅    0.001958
# 매    0.001964
# Length: 174, dtype: float64
#
#
# Keyword Significance Scores for "‘이낙연 탈당’에 광주 정치권 맹비난…“정치적 반란행위”":
# ------------------------------------------------------------------
# 이    0.015343
# 낙    0.006099
# 연    0.008611
#      0.271789
# 더    0.003656
#        ...
# 영    0.001319
# 활    0.001422
# 투    0.001675
# 쟁    0.001607
# 점    0.001379
# Length: 204, dtype: float64
#
#
# Keyword Significance Scores for "친윤 이철규, ‘윤심 공천’ 우려에 “당 계파 없어…한동훈 교감 안 해”":
# ---------------------------------------------------------------------------
# 관    0.010624
# 위    0.022709
#      0.273676
# 인    0.014155
# 선    0.007796
#        ...
# 영    0.005579
# 입    0.005365
# 체    0.003486
# 제    0.003529
# 유    0.002911
# Length: 116, dtype: float64
#
#
# Keyword Significance Scores for "이재명, 조연우 위원장 별세에 “남은 숙제는 저와 당에 맡겨달라”":
# -----------------------------------------------------------------------
# 이    0.022551
# 재    0.010388
# 명    0.008147
#      0.261517
# 더    0.008650
#        ...
# 한    0.005425
# 편    0.005085
# 퇴    0.004511
# 택    0.005052
# 료    0.003420
# Length: 84, dtype: float64
#
#
# Keyword Significance Scores for "“제2안철수의 길”…민주당, 이낙연 탈당 비난 봇물":
# ---------------------------------------------------------------
# 이    0.015254
# 낙    0.005863
# 연    0.006264
#      0.275628
# 민    0.017480
#        ...
# 한    0.002124
# 진    0.001993
# 결    0.002643
# 제    0.001792
# 활    0.001879
# Length: 177, dtype: float64
#
#
# Keyword Significance Scores for "빅텐트 ‘기호3번’ 노린다…이낙연과 3인방, 이준석도 ‘연대’":
# ---------------------------------------------------------------------
# 이    0.012865
# 낙    0.005850
# 연    0.012740
#      0.270848
# 더    0.005039
#        ...
# 보    0.003676
# 출    0.003247
# 재    0.003185
# 인    0.003198
# 역    0.002962
# Length: 120, dtype: float64
#
#
# Keyword Significance Scores for "이낙연 “누군가는 가야 길이 된다…새로운 길 동행해달라”":
# ------------------------------------------------------------------
# 이    0.012504
# 낙    0.006700
# 연    0.007469
#      0.264554
# 더    0.007512
#        ...
# 령    0.004607
# 권    0.004889
# 유    0.004673
# 계    0.004622
# 입    0.004649
# Length: 96, dtype: float64
#
#
# Keyword Significance Scores for "김은혜·방문규·염태영 등 출사표…경기도에 공직자출신 ‘출마 러시’":
# -----------------------------------------------------------------------
# 국    0.007363
# 회    0.008513
# 의    0.007663
# 원    0.011236
#      0.257715
#        ...
# 오    0.002466
# 늘    0.002257
# 련    0.002217
# 추    0.002283
# 처    0.001989
# Length: 147, dtype: float64
#
#
# Keyword Significance Scores for "최상목 “50인 미만 기업 중대법 유예, 국회서 신속 처리해야”":
# ----------------------------------------------------------------------
# 부    0.014332
# 총    0.008153
# 리    0.014278
#      0.264329
# 중    0.026289
#        ...
# 립    0.002732
# 극    0.002915
# 반    0.003097
# 영    0.002983
# 종    0.002015
# Length: 137, dtype: float64
#
#
# Keyword Significance Scores for "육·해군총장, 北포격에 서남해역 경계태세 점검…“합동작전 강화”":
# ----------------------------------------------------------------------
# 육    0.009583
# 군    0.014814
#      0.284234
# 참    0.006527
# 모    0.007784
#        ...
# 터    0.002537
# 축    0.003912
# 선    0.002175
# 첨    0.002523
# 단    0.002454
# Length: 143, dtype: float64
#
#
# Keyword Significance Scores for "與 공관위원장 “외부 공관위원 총선 불출마…윤심 개입 없어”":
# --------------------------------------------------------------------
# 합    0.002995
# 류    0.003397
#      0.279684
# 우    0.007615
# 려    0.007220
#        ...
# 절    0.002399
# 차    0.002395
# 시    0.002457
# 행    0.002454
# 택    0.002173
# Length: 145, dtype: float64
#
#
# Keyword Significance Scores for "당정 “연체채무 전액 상환자 최대 290만명 신용회복”":
# -----------------------------------------------------------------
# 김    0.005261
# 주    0.011622
# 현    0.008030
#      0.280535
# 금    0.011732
#        ...
# 약    0.006305
# 결    0.006739
# 조    0.007008
# 치    0.006804
# 행    0.004322
# Length: 70, dtype: float64
#
#
# Keyword Significance Scores for "당정, 코로나 소상공인 신용사면 검토…“통신채무 채무조정 고려”":
# ----------------------------------------------------------------------
# 김    0.002837
# 주    0.003064
# 현    0.003302
#      0.279958
# 금    0.020015
#        ...
# 병    0.001868
# 합    0.001769
# 보    0.001751
# 예    0.001755
# 재    0.001952
# Length: 161, dtype: float64
#
#
# Keyword Significance Scores for "박민식 前보훈부장관 “영등포을 출마…운동권 세력과 정면승부”":
# --------------------------------------------------------------------
# 박    0.004434
# 민    0.017739
# 식    0.005385
#      0.264698
# 국    0.013406
#        ...
# 학    0.005280
# 년    0.003213
# 물    0.003259
# 표    0.003211
# 우    0.002511
# Length: 119, dtype: float64
#
#
# Keyword Significance Scores for "한동훈 비대위 14일 첫 고위당정…설 민생대책 논의":
# ---------------------------------------------------------------
# 한    0.009445
# 동    0.012008
# 훈    0.006585
#      0.266205
# 국    0.014267
#        ...
# 우    0.003823
# 홍    0.003750
# 보    0.003431
# 근    0.003315
# 체    0.003351
# Length: 111, dtype: float64
#
#
# Keyword Significance Scores for "라오스 골든트라이앵글 ‘여행금지’ 발령 예정…“취업사기 급증”":
# ---------------------------------------------------------------------
# 라    0.021385
# 오    0.009044
# 스    0.021256
#      0.252534
# 골    0.005721
#        ...
# 레    0.003924
# 잔    0.002314
# 팔    0.002362
# 타    0.002399
# 동    0.001937
# Length: 143, dtype: float64
#
#
# Keyword Significance Scores for "정부, ‘취업사기 극성’ 라오스 북부 골든트라이앵글 2월부터 여행금지령":
# --------------------------------------------------------------------------
# 가    0.009716
# 자    0.007828
# 지    0.025255
# 구    0.010012
#      0.260744
#        ...
# 테    0.001865
# 속    0.002513
# 앞    0.001932
# 으    0.001943
# 황    0.001817
# Length: 180, dtype: float64
#
#
# Keyword Significance Scores for "러시아 관광객에 문 연 북한…연내 국경 개방 확대 조짐 지속":
# --------------------------------------------------------------------
# 북    0.021528
# 한    0.021011
#      0.270131
# 마    0.002879
# 식    0.002861
#        ...
# 와    0.001653
# 향    0.001751
# 여    0.001806
# 반    0.002702
# 때    0.001660
# Length: 175, dtype: float64
#
#
# Keyword Significance Scores for "김하중 변호사, ‘탈당’ 이원욱 지역구 출마 선언":
# --------------------------------------------------------------
# 김    0.006824
# 하    0.007590
# 중    0.011858
#      0.262351
# 변    0.017147
#        ...
# 조    0.004858
# 처    0.004764
# 임    0.005537
# 정    0.005306
# 봉    0.003952
# Length: 89, dtype: float64
#
#
# Keyword Significance Scores for "이낙연 탈당 “민주당, 1인-방탄정당 변질”":
# -----------------------------------------------------------
# 이    0.011764
# 낙    0.003636
# 연    0.003881
#      0.273613
# 더    0.005683
#        ...
# 태    0.002237
# 라    0.002325
# 고    0.002159
# 소    0.002291
# 영    0.001898
# Length: 163, dtype: float64
#
#
# Keyword Significance Scores for "강정애, 14개 중앙보훈단체 잇달아 방문…보훈업무 첫 공식 행보":
# ----------------------------------------------------------------------
# 강    0.004344
# 정    0.018200
#      0.276360
# 국    0.019058
# 가    0.016013
#        ...
# 운    0.002546
# 데    0.002516
# 책    0.002570
# 설    0.002600
# 개    0.002472
# Length: 143, dtype: float64
#
#
# Keyword Significance Scores for "조태용 “선거결과 영향 미치는 정치관여 안 할 것”":
# ---------------------------------------------------------------
# 조    0.008233
# 태    0.005968
# 용    0.006511
#      0.258588
# 국    0.024557
#        ...
# 임    0.003772
# 분    0.004227
# 충    0.004219
# 얘    0.004224
# 기    0.004254
# Length: 101, dtype: float64
#
#
# Keyword Significance Scores for "조태용 “北 김정은 체제 나름의 안정성 있어…올해 도발 수위 높아질 듯”":
# ---------------------------------------------------------------------------
# 조    0.008771
# 태    0.005743
# 용    0.004359
#      0.275391
# 국    0.010873
#        ...
# 휘    0.002759
# 판    0.002793
# 타    0.002801
# 설    0.002943
# 명    0.002322
# Length: 136, dtype: float64
#
#
# Keyword Significance Scores for "민주 “尹, 정부 요직 선후배·동기로 도배할 셈인가”":
# ----------------------------------------------------------------
# 신    0.008104
# 임    0.008359
#      0.271416
# 국    0.024810
# 민    0.026665
#        ...
# 성    0.004296
# 골    0.007283
# 품    0.004141
# 용    0.003981
# 경    0.003570
# Length: 87, dtype: float64
#
#
# Keyword Significance Scores for "‘95만채 공급’ 재건축으로만?…리모델링 추진 100만명 뿔났다":
# ----------------------------------------------------------------------
# 서    0.008235
# 울    0.008388
#      0.280474
# 영    0.002930
# 등    0.003001
#        ...
# 때    0.002461
# 문    0.002431
# 역    0.002526
# 할    0.002559
# 강    0.002151
# Length: 142, dtype: float64
#
#
# Keyword Significance Scores for "‘친윤 핵심’ 이철규 공관위 합류… 한동훈 “당 이끄는 건 저”":
# ----------------------------------------------------------------------
# 이    0.011131
# 철    0.005388
# 규    0.005567
#      0.273495
# 국    0.007645
#        ...
# 득    0.002155
# 력    0.002138
# 말    0.002117
# 씀    0.002180
# 박    0.001500
# Length: 168, dtype: float64
#
#
# Keyword Significance Scores for "김종민 “이낙연 신당 합류…대통령 만드는 걸로 오해할 수도”":
# --------------------------------------------------------------------
# 위    0.004267
# 험    0.004922
#      0.278797
# 결    0.005346
# 단    0.005260
#        ...
# 객    0.003434
# 여    0.003628
# 군    0.003658
# 활    0.003603
# 약    0.003315
# Length: 124, dtype: float64
#
#
# Keyword Significance Scores for "조태용 청문회, ‘병역·증여세’ 등 자료제출 공방…1시간만 정회":
# ----------------------------------------------------------------------
# 재    0.006088
# 산    0.006149
#      0.275593
# 자    0.029650
# 료    0.018058
#        ...
# 합    0.001970
# 필    0.001995
# 선    0.002212
# 언    0.002267
# 속    0.001786
# Length: 147, dtype: float64
#
#
# Keyword Significance Scores for "민주당 129명, 이낙연 탈당 만류…“분열의 길 이끌어선 안돼”":
# ----------------------------------------------------------------------
# 강    0.010420
# 득    0.005529
# 구    0.009578
#      0.265877
# 더    0.004783
#        ...
# 식    0.003033
# 언    0.002896
# 직    0.002832
# 출    0.003193
# 김    0.003421
# Length: 122, dtype: float64
#
#
# Keyword Significance Scores for "탈당 이원욱 “이재명-정성호 병상문자, 국정농단과 뭐가 다르냐”":
# ----------------------------------------------------------------------
# 이    0.018305
# 재    0.008921
# 명    0.009626
#      0.265289
# 더    0.006026
#        ...
# 만    0.002293
# 마    0.002526
# 막    0.002794
# 외    0.002817
# 통    0.002577
# Length: 148, dtype: float64
#
#
# Keyword Significance Scores for "日, 북한 미사일 발사 등 감시할 정보위성 발사…궤도 진입 성공":
# ----------------------------------------------------------------------
# 고    0.009169
# 도    0.015664
#      0.288763
# 지    0.010768
# 구    0.007582
#        ...
# 대    0.004863
# 체    0.004862
# 난    0.004616
# 실    0.004827
# 패    0.004827
# Length: 87, dtype: float64
#
#
# Keyword Significance Scores for "2020년 北 국경폐쇄후 처음으로 러 관광객들 북한으로 스키여행":
# ----------------------------------------------------------------------
# 무    0.007961
# 기    0.009577
#      0.265228
# 공    0.006611
# 급    0.003786
#        ...
# 거    0.002616
# 본    0.002379
# 성    0.002661
# 명    0.002784
# 표    0.001911
# Length: 136, dtype: float64
#
#
# Keyword Significance Scores for "文 전 대통령, 홍익표 만나 “조금 더 통합적으로 당 운영해야”":
# ----------------------------------------------------------------------
# 문    0.007881
# 재    0.011078
# 인    0.009103
#      0.265574
# 대    0.033623
#        ...
# 격    0.004336
# 유    0.004777
# 김    0.006292
# 혜    0.005153
# 린    0.004201
# Length: 107, dtype: float64
#
#
# Keyword Significance Scores for "대검, ‘정치적 중립위반’ 김상민 검사 중징계 청구":
# ---------------------------------------------------------------
# 검    0.038639
# 찰    0.015355
# 청    0.007797
#      0.285247
# 정    0.011894
#        ...
# 록    0.003700
# 외    0.003598
# 접    0.003675
# 촉    0.003675
# 봉    0.002435
# Length: 108, dtype: float64
#
#
# Keyword Significance Scores for "이낙연 탈당 후 양산 달려간 홍익표…文 “하나돼야 총선 승리”":
# ---------------------------------------------------------------------
# 문    0.006213
# 재    0.006545
# 인    0.008332
#      0.273994
# 대    0.031900
#        ...
# 소    0.002702
# 관    0.002640
# 련    0.002618
# 말    0.002709
# 씀    0.002709
# Length: 142, dtype: float64
#
#
# Keyword Significance Scores for "‘뇌물 수수 의혹’ 노웅래 “위헌법률심판 제청” vs 검찰 “재판 지연 의도”":
# ------------------------------------------------------------------------------
# 노    0.003749
# 웅    0.004135
# 래    0.004822
#      0.258249
# 더    0.004717
#        ...
# 명    0.002549
# 례    0.002558
# 난    0.002649
# 해    0.002793
# 속    0.002675
# Length: 129, dtype: float64
#
#
# Keyword Significance Scores for "野공관위 “증오-폭력발언 공천에 반영”…계파 잡음엔 “친명 비명 없다”":
# --------------------------------------------------------------------------
# 임    0.003099
# 혁    0.003426
# 백    0.003812
#      0.271789
# 더    0.003642
#        ...
# 좌    0.002396
# 우    0.002547
# 분    0.002677
# 령    0.002488
# 윤    0.002136
# Length: 161, dtype: float64
#
#
# Keyword Significance Scores for "대통령실 “신년 기자회견·제2부속실 여러 가지로 검토중”":
# ------------------------------------------------------------------
# 용    0.006052
# 산    0.006665
#      0.270393
# 대    0.029551
# 통    0.022463
#        ...
# 선    0.004490
# 약    0.004576
# 출    0.004663
# 범    0.004769
# 폐    0.003799
# Length: 90, dtype: float64
#
#
# Keyword Significance Scores for "대통령실, ‘바이든-날리면’ 정정보도 선고에 “정부·외교 신뢰 회복 계기”":
# ----------------------------------------------------------------------------
# 이    0.010343
# 도    0.022121
# 우    0.004670
#      0.277155
# 홍    0.003270
#        ...
# 다    0.002602
# 하    0.002416
# 루    0.002344
# 급    0.002182
# 혜    0.001991
# Length: 164, dtype: float64
#
#
# Keyword Significance Scores for "野탈당 3인 ‘미래대연합’, 이낙연 ‘새로운 미래’…합종연횡 본격화":
# ------------------------------------------------------------------------
# 더    0.003625
# 불    0.004970
# 어    0.003992
# 민    0.009191
# 주    0.006085
#        ...
# 결    0.001689
# 텐    0.001839
# 트    0.001927
# 필    0.001846
# 리    0.001275
# Length: 194, dtype: float64
#
#
# Keyword Significance Scores for "대통령실, ‘바이든 날리면’ 정정보도 판결에 “정부신뢰 회복 계기”":
# ------------------------------------------------------------------------
# 윤    0.004447
# 석    0.009281
# 열    0.005520
#      0.276401
# 대    0.017876
#        ...
# 향    0.003695
# 허    0.003728
# 책    0.003491
# 임    0.003602
# 적    0.002367
# Length: 118, dtype: float64
#
#
# Keyword Significance Scores for "美, 北 탄도미사일 수송 러 국영항공사 등 제재":
# -------------------------------------------------------------
# 토    0.003571
# 니    0.003861
#      0.266849
# 미    0.014177
# 국    0.017053
#        ...
# 래    0.002639
# 워    0.003273
# 싱    0.003247
# 턴    0.003340
# 특    0.002632
# Length: 130, dtype: float64
#
#
# Keyword Significance Scores for "한동훈 지지율 22%, 이재명 턱밑…피습 ‘동정론’은 없었다":
# --------------------------------------------------------------------
# 한    0.004048
# 동    0.009831
# 훈    0.003203
#      0.276999
# 국    0.008288
#        ...
# 페    0.002196
# 참    0.002096
# 하    0.002411
# 면    0.002579
# 된    0.002096
# Length: 154, dtype: float64
#
#
# Keyword Significance Scores for "與, 황운하·노웅래 출마 적격 판정에 “불공정 공천 현실화”":
# --------------------------------------------------------------------
# 심    0.008052
# 사    0.015044
#      0.277078
# 기    0.010964
# 준    0.004390
#        ...
# 다    0.002951
# 음    0.003170
# 총    0.002967
# 쟁    0.002698
# 종    0.002912
# Length: 128, dtype: float64
#
#
# Keyword Significance Scores for "문재인 “통합적 운영해야”…홍익표 “국가원로 역할 해달라”":
# -------------------------------------------------------------------
# 홍    0.004072
# 익    0.004480
# 표    0.020337
#      0.268573
# 경    0.008580
#        ...
# 올    0.002995
# 거    0.002949
# 교    0.003148
# 노    0.003246
# 력    0.003292
# Length: 117, dtype: float64
#
#
# Keyword Significance Scores for "“저도 한가입니다” 한동훈 한마디에 빵 터졌다":
# ------------------------------------------------------------
# 국    0.009543
# 민    0.017340
#      0.260683
# 한    0.020656
# 동    0.008805
#        ...
# 아    0.003864
# 합    0.003594
# 개    0.003364
# 혜    0.003650
# 선    0.002969
# Length: 105, dtype: float64
#
#
# Keyword Significance Scores for "양산 통도사 찾은 한동훈 “불교, 우리 전통문화와 정신의 핵심…중요하게 생각”":
# ------------------------------------------------------------------------------
# 통    0.017550
# 도    0.017272
# 사    0.018038
#      0.260865
# 조    0.008382
#        ...
# 윤    0.004154
# 석    0.005645
# 박    0.004098
# 출    0.004133
# 진    0.003992
# Length: 102, dtype: float64
#
#
# Keyword Significance Scores for "‘바이든 보도’ 정정판결에 민주 “진위 모른다며 무슨 근거로”":
# ---------------------------------------------------------------------
# 윤    0.006131
# 석    0.006620
# 열    0.007017
#      0.266285
# 대    0.019335
#        ...
# 조    0.003202
# 절    0.003380
# 차    0.003380
# 청    0.003434
# 구    0.003542
# Length: 108, dtype: float64
#
#
# Keyword Significance Scores for "정청래 “경찰, 이재명 핏자국 지워 증거인멸” 특검 거론…與 “음모론 여론몰이”":
# -------------------------------------------------------------------------------
# 보    0.001680
# 기    0.009316
#      0.273346
# 정    0.009724
# 청    0.007672
#        ...
# 멍    0.002477
# 통    0.002406
# 상    0.002472
# 화    0.002964
# 영    0.002442
# Length: 148, dtype: float64
#
#
# Keyword Significance Scores for "신원식, 국방과학연구소 첫 방문…“초정밀·고위력 무기개발 박차”":
# ----------------------------------------------------------------------
# 순    0.006663
# 직    0.007060
#      0.278352
# 연    0.019945
# 구    0.021813
#        ...
# 이    0.003699
# 날    0.003662
# 그    0.004248
# 동    0.004213
# 안    0.004263
# Length: 109, dtype: float64
#
#
# Keyword Significance Scores for "문재인, 홍익표 만나 “민주당 통합적으로 운영해야” 당부":
# ------------------------------------------------------------------
# 홍    0.004917
# 익    0.005256
# 표    0.023730
#      0.264314
# 더    0.005865
#        ...
# 복    0.004053
# 귀    0.003819
# 유    0.004856
# 충    0.003811
# 격    0.003923
# Length: 105, dtype: float64
#
#
# Keyword Significance Scores for "국힘, ‘바이든 날리면’ 정정보도 판결에 “MBC 사과하라”":
# --------------------------------------------------------------------
# 국    0.024598
# 민    0.019348
#      0.275081
# 윤    0.007950
# 재    0.004589
#        ...
# 치    0.007044
# 책    0.004357
# 임    0.004371
# 산    0.004181
# 강    0.003615
# Length: 103, dtype: float64
#
#
# Keyword Significance Scores for "김무성, 내주 출마 선언…부산 중·영도 격전지 부상":
# ---------------------------------------------------------------
# 김    0.003180
# 무    0.008675
# 성    0.006492
#      0.275040
# 미    0.003588
#        ...
# 생    0.002681
# 교    0.002694
# 육    0.002578
# 흥    0.002307
# 준    0.001843
# Length: 146, dtype: float64
#
#
# Keyword Significance Scores for "이낙연, 신당 가칭 ‘새로운 미래’ 발표…“극단의 정치 타파”":
# ---------------------------------------------------------------------
# 정    0.025440
# 식    0.004918
#      0.270344
# 당    0.052100
# 명    0.011184
#        ...
# 재    0.003634
# 책    0.003499
# 비    0.003586
# 시    0.003602
# 봉    0.002469
# Length: 104, dtype: float64
#
#
# Keyword Significance Scores for "홍익표, 비명 3인·이낙연 탈당에 “강물은 결국 바다에서 만나”":
# ----------------------------------------------------------------------
# 방    0.008911
# 식    0.006106
#      0.270750
# 생    0.013238
# 각    0.013058
#        ...
# 술    0.002883
# 외    0.002881
# 청    0.002744
# 업    0.002470
# 배    0.002353
# Length: 147, dtype: float64
#
#
# Keyword Significance Scores for "허은아, ‘여성 그림 비상구’ 추가에 “국민 세금 갖고 장난하나”":
# -----------------------------------------------------------------------
# 비    0.020510
# 상    0.018009
# 구    0.012785
#      0.261605
# 남    0.007417
#        ...
# 인    0.004543
# 벼    0.004807
# 랑    0.005375
# 강    0.004923
# 조    0.003632
# Length: 99, dtype: float64
#
#
# Keyword Significance Scores for "이태원 특별법 거부권 뜸들이는 尹…“법리적 비판은 별개 문제”":
# ---------------------------------------------------------------------
# 윤    0.003717
# 석    0.004111
# 열    0.004448
#      0.272107
# 대    0.021299
#        ...
# 려    0.003794
# 현    0.002498
# 잘    0.002812
# 못    0.002690
# 보    0.002647
# Length: 130, dtype: float64
#
#
# Keyword Significance Scores for "외교부 “MBC 허위보도 대단히 무책임…외교 신뢰회복 계기”":
# --------------------------------------------------------------------
# 바    0.005339
# 이    0.014857
# 든    0.006304
#      0.277162
# 외    0.018055
#        ...
# 명    0.002723
# 론    0.003129
# 중    0.003173
# 제    0.004145
# 유    0.002691
# Length: 131, dtype: float64
#
#
# Keyword Significance Scores for "한동훈 방문한 양산 통도사…국힘 지지자 “힘내라” 연호":
# -----------------------------------------------------------------
# 한    0.008570
# 동    0.012825
# 훈    0.009466
#      0.259189
# 국    0.006230
#        ...
# 참    0.003174
# 만    0.002940
# 식    0.003270
# 덕    0.003300
# 난    0.002949
# Length: 114, dtype: float64
#
#
# Keyword Significance Scores for "이재명측 “당분간 출석 어렵다” vs 재판부 “그러면 끝 없어…李없어도 23일 재개”":
# ----------------------------------------------------------------------------------
# 흉    0.003685
# 기    0.014727
#      0.272360
# 피    0.006239
# 습    0.008541
#        ...
# 산    0.003082
# 덕    0.003299
# 항    0.002834
# 격    0.003027
# 경    0.002212
# Length: 122, dtype: float64
#
#
# Keyword Significance Scores for "전·현직 의원부터 장·차관 출신 득실…국힘 내부 경쟁 치열한 ‘이곳’은?":
# ---------------------------------------------------------------------------
# 한    0.002216
# 동    0.004255
# 훈    0.004562
#      0.270093
# 국    0.009056
#        ...
# 복    0.001698
# 청    0.001703
# 반    0.001916
# 면    0.001873
# 백    0.001653
# Length: 175, dtype: float64
#
#
# Keyword Significance Scores for "뷰티 전문가로 변신한 북한 여성 돌격대원[주성하의 북에서 온 이웃]":
# ------------------------------------------------------------------------
# 한    0.006010
# 국    0.011822
#      0.277162
# 입    0.002469
# 피    0.004982
#        ...
# 확    0.000784
# 효    0.000794
# 또    0.000911
# 래    0.000910
# 획    0.000794
# Length: 321, dtype: float64
#
#
# Keyword Significance Scores for "홍준표 “달빛철도법 대표발의자 무책임, 총선서 책임 물어야”":
# --------------------------------------------------------------------
# 홍    0.003890
# 준    0.004967
# 표    0.016062
#      0.278943
# 대    0.022669
#        ...
# 류    0.003248
# 눈    0.003337
# 애    0.002029
# 력    0.003218
# 입    0.003057
# Length: 145, dtype: float64
#
#
# Keyword Significance Scores for "北 선전매체들, 이틀째 접속 안돼…개편 위한 차단 추측":
# -----------------------------------------------------------------
# 북    0.020203
# 한    0.017864
#      0.265161
# 선    0.029924
# 전    0.023011
#        ...
# 비    0.003726
# 말    0.003427
# 회    0.003502
# 계    0.003332
# 취    0.003325
# Length: 108, dtype: float64
#
#
# Keyword Significance Scores for "조태열 “강제동원 문제, 함께 배 타는 마음으로…日기업 동참해야”":
# -----------------------------------------------------------------------
# 조    0.007186
# 태    0.004097
# 열    0.005764
#      0.280125
# 외    0.009909
#        ...
# 쟁    0.002218
# 요    0.002135
# 획    0.002203
# 운    0.002340
# 데    0.002362
# Length: 156, dtype: float64
#
#
# Keyword Significance Scores for "‘산불 골프 의혹’ 김진태 “수사 이후로 선고 늦춰달라”":
# ------------------------------------------------------------------
# 김    0.005358
# 진    0.007496
# 태    0.007755
#      0.275334
# 상    0.013604
#        ...
# 당    0.004509
# 술    0.003565
# 자    0.003492
# 리    0.003552
# 련    0.002799
# Length: 122, dtype: float64
#
#
# Keyword Significance Scores for "원칙과상식, ‘미래대연합’ 창당…“설 연휴 전 대연합 세력 출범”":
# -----------------------------------------------------------------------
# 탈    0.003074
# 당    0.019707
#      0.283529
# 명    0.004567
# 계    0.005282
#        ...
# 축    0.001625
# 역    0.001557
# 감    0.001488
# 말    0.001853
# 씀    0.001476
# Length: 192, dtype: float64
#
#
# Keyword Significance Scores for "천하람 “개혁신당 20일 창당 완료…이낙연 속도 내서 실기 않기를”":
# ------------------------------------------------------------------------
# 업    0.005275
# 그    0.005615
# 레    0.006342
# 이    0.022580
# 드    0.008362
#        ...
# 치    0.003420
# 미    0.003686
# 래    0.004190
# 보    0.003950
# 탬    0.002932
# Length: 112, dtype: float64
#
#
# Keyword Significance Scores for "‘흉기 피습’ 이재명 “1월 재판 출석 어렵다”…재판부 “그러면 끝이 없다”":
# -----------------------------------------------------------------------------
# 흉    0.005753
# 기    0.016960
#      0.267580
# 피    0.006500
# 습    0.008995
#        ...
# 임    0.003048
# 예    0.005919
# 산    0.003156
# 덕    0.003370
# 격    0.003129
# Length: 121, dtype: float64
#
#
# Keyword Significance Scores for "어딘지도 모르는데 종류도 제각각…행안부 “대피소 공동활용 추진”":
# ----------------------------------------------------------------------
# 재    0.020943
# 난    0.018844
#      0.271993
# 유    0.005220
# 형    0.005294
#        ...
# 음    0.003301
# 티    0.003254
# 맵    0.003068
# 검    0.002779
# 색    0.002771
# Length: 121, dtype: float64
#
#
# Keyword Significance Scores for "‘흉기관통’ 이재명 셔츠, 의료용 쓰레기봉투서 폐기 직전 발견":
# ---------------------------------------------------------------------
# 피    0.011461
# 습    0.010206
#      0.259766
# 당    0.014599
# 시    0.010622
#        ...
# 과    0.004069
# 브    0.004211
# 핑    0.003919
# 설    0.003457
# 혜    0.002855
# Length: 102, dtype: float64
#
#
# Keyword Significance Scores for "김용남, 이준석 품에…“尹에게 국민도 속고 저도 속았다”":
# ------------------------------------------------------------------
# 김    0.002271
# 용    0.004457
# 남    0.002726
#      0.273759
# 국    0.016010
#        ...
# 형    0.001830
# 태    0.001820
# 덩    0.001765
# 투    0.001615
# 너    0.001653
# Length: 192, dtype: float64
#
#
# Keyword Significance Scores for "조태열 “北 도발에 대응 ‘단호·절제’…국제연대가 해답”":
# ------------------------------------------------------------------
# 취    0.002801
# 임    0.005521
#      0.284427
# 기    0.010540
# 자    0.004659
#        ...
# 러    0.001554
# 직    0.001969
# 좌    0.001322
# 념    0.001290
# 독    0.001210
# Length: 223, dtype: float64
#
#
# Keyword Significance Scores for "여당, ‘1호 인재’ 박상수 논란에 “비공개 SNS 발언 검토 논의”":
# -------------------------------------------------------------------------
# 국    0.010985
# 민    0.011602
#      0.277278
# 판    0.010016
# 단    0.007834
#        ...
# 피    0.003475
# 소    0.003570
# 고    0.004211
# 응    0.004057
# 수    0.003025
# Length: 110, dtype: float64
#
#
# Keyword Significance Scores for "與 인재영입위, 3명 인재 영입…이레나·강철호·전상범":
# ----------------------------------------------------------------
# 과    0.007036
# 학    0.016732
#      0.274437
# 법    0.006681
# 조    0.005129
#        ...
# 호    0.001957
# 처    0.002112
# 리    0.002081
# 람    0.002029
# 심    0.002018
# Length: 159, dtype: float64
#
#
# Keyword Significance Scores for "국힘 인재영입위, 이레나·강철호·전상범 영입":
# -----------------------------------------------------------
# 왼    0.001581
# 쪽    0.001944
#      0.278325
# 레    0.004567
# 나    0.003420
#        ...
# 증    0.001752
# 환    0.001707
# 본    0.001668
# 거    0.001641
# 토    0.001831
# Length: 181, dtype: float64
#
#
# Keyword Significance Scores for "멈췄던 ‘대장동 재판’ 1월 말 재개…이재명 출석은 불투명":
# -------------------------------------------------------------------
# 대    0.018384
# 장    0.007298
# 동    0.011549
#      0.273224
# 백    0.002743
#        ...
# 골    0.001837
# 편    0.001804
# 응    0.001858
# 헬    0.001798
# 송    0.001867
# Length: 179, dtype: float64
#
#
# Keyword Significance Scores for "이재명 ‘피습 셔츠’ 부산대병원 아닌 진주서 수거, 왜?":
# ------------------------------------------------------------------
# 피    0.010430
# 습    0.004912
#      0.259046
# 당    0.014118
# 시    0.009716
#        ...
# 멍    0.003964
# 통    0.003553
# 크    0.003361
# 맥    0.003904
# 손    0.003866
# Length: 99, dtype: float64
#
#
# Keyword Significance Scores for "이재명 “혁신·통합 공천으로 이기는 민주당 돼야”":
# --------------------------------------------------------------
# 관    0.014292
# 위    0.008188
#      0.273432
# 회    0.016472
# 의    0.011548
#        ...
# 서    0.004294
# 통    0.004118
# 합    0.004123
# 변    0.004117
# 화    0.004116
# Length: 100, dtype: float64
#
#
# Keyword Significance Scores for "조태열 외교 “이번엔 中 시진핑 방한할 차례…합당한 순서”":
# -------------------------------------------------------------------
# 조    0.007840
# 태    0.003766
# 열    0.005778
#      0.275053
# 외    0.009639
#        ...
# 율    0.002832
# 갈    0.003016
# 등    0.003010
# 해    0.002798
# 강    0.002309
# Length: 137, dtype: float64
#
#
# Keyword Significance Scores for "한동훈, ‘차기 대통령 선호도’ 최고치…이재명 바짝 추격":
# ------------------------------------------------------------------
# 한    0.006760
# 동    0.008169
# 훈    0.004647
#      0.270129
# 국    0.009393
#        ...
# 페    0.002361
# 참    0.002189
# 하    0.002490
# 면    0.002737
# 된    0.002232
# Length: 149, dtype: float64
#
#
# Keyword Significance Scores for "민주, ‘국민참여 공천제’ 실시…“혁신과 통합이 원칙”":
# -----------------------------------------------------------------
# 임    0.003679
# 혁    0.008712
# 백    0.004019
#      0.269326
# 더    0.004894
#        ...
# 열    0.002198
# 쇠    0.002162
# 립    0.002196
# 투    0.002132
# 망    0.002026
# Length: 154, dtype: float64
#
#
# Keyword Significance Scores for "이낙연 “이준석과 함께 해야…세대통합 모델될 수 있어”":
# -----------------------------------------------------------------
# 이    0.013592
# 낙    0.003292
# 연    0.009359
#      0.269432
# 더    0.005087
#        ...
# 심    0.003883
# 점    0.002409
# 그    0.002538
# 때    0.002583
# 호    0.001876
# Length: 154, dtype: float64
#
#
# Keyword Significance Scores for "‘탈당’ 비명 3인, ‘미래대연합’ 창당 선언…박원석-정태근 동참":
# -----------------------------------------------------------------------
# 더    0.003009
# 불    0.006653
# 어    0.004423
# 민    0.014652
# 주    0.007866
#        ...
# 도    0.003570
# 덕    0.003533
# 복    0.003343
# 뢰    0.003308
# 봉    0.002243
# Length: 119, dtype: float64
#
#
# Keyword Significance Scores for "민주당 공관위장 “국민참여 공천 실시…증오-폭력발언 공천기준 반영”":
# ------------------------------------------------------------------------
# 공    0.038986
# 천    0.032925
#      0.280654
# 관    0.014241
# 리    0.008350
#        ...
# 요    0.004150
# 조    0.009735
# 건    0.004172
# 강    0.004172
# 혜    0.003320
# Length: 98, dtype: float64
#
#
# Keyword Significance Scores for "김정은→기시다 서한 뒤 日 비난 자제하는 北…대일정책 계산법에 주목":
# ------------------------------------------------------------------------
# 북    0.013850
# 한    0.014497
#      0.275795
# 노    0.008882
# 동    0.007433
#        ...
# 송    0.001618
# 폐    0.001481
# 포    0.001501
# 계    0.001553
# 메    0.001506
# Length: 195, dtype: float64
#
#
# Keyword Significance Scores for "尹대통령, 관료사회 ‘복지부동’에 답답…내각제까지 거론":
# -----------------------------------------------------------------
# 윤    0.003431
# 석    0.008036
# 열    0.005662
#      0.274067
# 대    0.023008
#        ...
# 락    0.002763
# 달    0.002650
# 라    0.004673
# 드    0.002630
# 브    0.002843
# Length: 131, dtype: float64
#
#
# Keyword Significance Scores for "홍문표, ‘윤심 공천’ 우려에 “한동훈 역할 중요…당무감사 공개해야”":
# -------------------------------------------------------------------------
# 이    0.007250
# 철    0.004693
# 규    0.005005
#      0.273644
# 공    0.014627
#        ...
# 희    0.003050
# 특    0.002499
# 검    0.002526
# 스    0.002540
# 크    0.002565
# Length: 148, dtype: float64
#
#
# Keyword Significance Scores for "법원 “尹 ‘바이든 vs 날리면’ 논란, MBC 정정보도하라”…외교부 승소":
# ----------------------------------------------------------------------------
# 항    0.002572
# 소    0.007708
#      0.274205
# 유    0.004883
# 튜    0.002314
#        ...
# 불    0.002036
# 견    0.002053
# 출    0.002027
# 변    0.002160
# 종    0.002109
# Length: 172, dtype: float64
#
#
# Keyword Significance Scores for "與, ‘이재명 특혜’ 겨냥 “지역 위급환자 서울 오지 않는 체계 구축할 것”":
# -----------------------------------------------------------------------------
# 지    0.012921
# 역    0.010127
#      0.284093
# 의    0.036352
# 대    0.016668
#        ...
# 죄    0.001394
# 직    0.001431
# 질    0.001431
# 찰    0.002131
# 쟁    0.001424
# Length: 195, dtype: float64
#
#
# Keyword Significance Scores for "이낙연, 지지자 ‘이재명 칼빵’ 막말 사과…민주 “반인륜적 망언”":
# -----------------------------------------------------------------------
# 일    0.003765
# 부    0.006407
#      0.272806
# 지    0.028544
# 자    0.012830
#        ...
# 막    0.002492
# 말    0.002434
# 염    0.002306
# 즉    0.002132
# 흥    0.002111
# Length: 169, dtype: float64
#
#
# Keyword Significance Scores for "이준석 개혁신당, 20일 공식 출범…중앙당 창당대회 개최":
# ------------------------------------------------------------------
# 이    0.013476
# 준    0.009708
# 석    0.005540
#      0.272232
# 개    0.015544
#        ...
# 과    0.004521
# 때    0.002892
# 문    0.002981
# 효    0.002918
# 율    0.002978
# Length: 129, dtype: float64
#
#
# Keyword Significance Scores for "류호정 “탈당은 없다…정의당 민주당 2중대 아닌 제3지대로”":
# --------------------------------------------------------------------
# 정    0.028233
# 의    0.040804
# 당    0.051104
#      0.279549
# 원    0.018909
#        ...
# 느    0.004885
# 낌    0.004999
# 얘    0.004774
# 라    0.005108
# 고    0.003932
# Length: 84, dtype: float64
#
#
# Keyword Significance Scores for "이재명 “민주주의 퇴행의 시대…문익환 목사 용기에서 답을 찾겠다”":
# -----------------------------------------------------------------------
# 흉    0.002893
# 기    0.013266
#      0.261057
# 피    0.004534
# 습    0.004501
#        ...
# 모    0.004808
# 란    0.004659
# 념    0.004374
# 제    0.004508
# 예    0.003932
# Length: 103, dtype: float64
#
#
# Keyword Significance Scores for "북한, 남파간첩 지령 ‘평양방송’ 중단…대남교류 단체도 정리":
# --------------------------------------------------------------------
# 북    0.013636
# 한    0.012977
#      0.269262
# 노    0.007176
# 동    0.011504
#        ...
# 면    0.002042
# 추    0.002278
# 측    0.002260
# 예    0.002347
# 슬    0.001937
# Length: 158, dtype: float64
#
#
# Keyword Significance Scores for "이상민 “국힘 중진, 신랄히 얘기…민주 중진들은 말 한마디 안 해”":
# ------------------------------------------------------------------------
# 중    0.008275
# 진    0.009124
#      0.275537
# 문    0.004614
# 제    0.008064
#        ...
# 차    0.002984
# 관    0.003028
# 출    0.004623
# 예    0.002787
# 본    0.002799
# Length: 135, dtype: float64
#
#
# Keyword Significance Scores for "“한반도 상황, 6·25 직전만큼 위험…김정은, 전쟁 나설 결심”":
# -----------------------------------------------------------------------
# 북    0.015523
# 한    0.018991
#      0.271134
# 노    0.013295
# 동    0.006848
#        ...
# 법    0.002703
# 확    0.002688
# 용    0.002654
# 사    0.002662
# 승    0.003703
# Length: 145, dtype: float64
#
#
# Keyword Significance Scores for "“이재명 일정에 맞추면 끝없어”…법원, 당분간 ‘李없는 李재판’ 진행키로[법조 Zoom In/대장동 재판 따라잡기]":
# ---------------------------------------------------------------------------------------------------
# 경    0.003781
# 기    0.009046
#      0.277106
# 성    0.004612
# 남    0.006070
#        ...
# 간    0.001907
# 파    0.002102
# 악    0.001323
# 여    0.001308
# 투    0.001263
# Length: 214, dtype: float64
#
#
# Keyword Significance Scores for "류호정 “탈당 안한다…정의당 ‘민주당 2중대’ 아닌 제3지대로 가야”":
# -------------------------------------------------------------------------
# 개    0.009627
# 인    0.009866
#      0.287890
# 활    0.017504
# 동    0.015880
#        ...
# 론    0.003763
# 청    0.004246
# 예    0.004078
# 목    0.004001
# 강    0.003586
# Length: 95, dtype: float64
#
#
# Keyword Significance Scores for "“北, 작년 中선박 33척 구매…전년 대비 5배 증가”":
# -----------------------------------------------------------------
# 자    0.005892
# 료    0.006459
#      0.281717
# 사    0.014284
# 진    0.004274
#        ...
# 동    0.006247
# 불    0.004160
# 법    0.004480
# 행    0.004277
# 심    0.002824
# Length: 97, dtype: float64
#
#
# Keyword Significance Scores for "장만채 前 전남도교육감 민주당 탈당 ‘이낙연 신당’ 합류하나":
# --------------------------------------------------------------------
# 이    0.024739
# 낙    0.007647
# 연    0.008140
#      0.262966
# 더    0.005108
#        ...
# 조    0.003513
# 응    0.003299
# 바    0.003231
# 람    0.003496
# 안    0.002386
# Length: 118, dtype: float64
#
#
# Keyword Significance Scores for "‘피습’ 회복 중 이재명 “민주주의 무너진 퇴행의 시대 문익환 용기 기억”":
# ----------------------------------------------------------------------------
# 흉    0.004795
# 기    0.017046
#      0.263940
# 피    0.008238
# 습    0.010499
#        ...
# 모    0.006594
# 추    0.003796
# 배    0.003697
# 념    0.003668
# 제    0.002623
# Length: 107, dtype: float64
#
#
# Keyword Significance Scores for "[단독]“北, 작년 러서 사치품 수백만달러 반입… 무기제공 대가인 듯”":
# --------------------------------------------------------------------------
# 무    0.004253
# 기    0.007079
#      0.262370
# 사    0.016187
# 치    0.010239
#        ...
# 협    0.002053
# 력    0.002024
# 측    0.001950
# 진    0.002094
# 규    0.001478
# Length: 168, dtype: float64
#
#
# Keyword Significance Scores for "野탈당 3인 ‘미래대연합’, 이낙연 ‘새로운 미래’… 합종연횡 본격화":
# -------------------------------------------------------------------------
# 신    0.010439
# 당    0.029288
#      0.269579
# 박    0.003604
# 원    0.015012
#        ...
# 결    0.001628
# 텐    0.001785
# 트    0.001866
# 필    0.001786
# 리    0.001180
# Length: 198, dtype: float64
#
#
# Keyword Significance Scores for "野공관위 “증오-폭력발언, 공천에 반영”":
# ---------------------------------------------------------
# 임    0.003440
# 혁    0.003817
# 백    0.004143
#      0.275151
# 위    0.015775
#        ...
# 도    0.002353
# 과    0.002445
# 안    0.002312
# 해    0.002370
# 윤    0.002453
# Length: 148, dtype: float64
#
#
# Keyword Significance Scores for "與 “1말2초 수도권 공천, 2말3초 영남… 승부처부터 마무리”":
# ----------------------------------------------------------------------
# 관    0.010874
# 위    0.017353
#      0.261691
# 회    0.008729
# 의    0.010253
#        ...
# 협    0.002311
# 절    0.002704
# 물    0.002749
# 안    0.005132
# 용    0.001776
# Length: 140, dtype: float64
#
#
# Keyword Significance Scores for "野 “이재명 피습 은폐 의혹 재수사해야”… 與 “음모론 여론몰이”":
# -----------------------------------------------------------------------
# 현    0.004699
# 장    0.009414
#      0.273654
# 청    0.008029
# 소    0.009818
#        ...
# 통    0.002508
# 상    0.002583
# 진    0.002624
# 화    0.003072
# 영    0.002529
# Length: 143, dtype: float64
#
#
# Keyword Significance Scores for "“北, 김정은 ‘대남기구 정리’ 지시따라 통일전선부 통폐합 수순”":
# -----------------------------------------------------------------------
# 선    0.006749
# 희    0.001821
#      0.272971
# 외    0.009030
# 무    0.009596
#        ...
# 페    0.002213
# 말    0.001379
# 련    0.001397
# 름    0.001580
# 길    0.001583
# Length: 190, dtype: float64
#
#
# Keyword Significance Scores for "위원장 셀프민원 공방속…  방심위, 야권위원 2명 해촉건의 ‘충돌’":
# ------------------------------------------------------------------------
# 비    0.005896
# 밀    0.002334
#      0.275728
# 유    0.010653
# 지    0.013576
#        ...
# 술    0.001898
# 족    0.001683
# 초    0.001704
# 단    0.001769
# 태    0.001694
# Length: 166, dtype: float64
#
#
# Keyword Significance Scores for "[주성하 기자의 서울과 평양사이]도발의 시간이 다가오고 있다":
# --------------------------------------------------------------------
# 김    0.013260
# 정    0.016958
# 은    0.007686
#      0.276893
# 새    0.002930
#        ...
# 불    0.001610
# 즉    0.001479
# 거    0.001403
# 향    0.001434
# 순    0.001421
# Length: 224, dtype: float64
#
#
# Keyword Significance Scores for "한미일, 北 탄도미사일 발사에 “도발할수록 3국 안보협력 강화”":
# ----------------------------------------------------------------------
# 우    0.002634
# 리    0.013022
# 나    0.003828
# 라    0.008752
#      0.272574
#        ...
# 예    0.003234
# 주    0.003155
# 개    0.003098
# 만    0.003375
# 큼    0.003332
# Length: 112, dtype: float64
#
#
# Keyword Significance Scores for "日 “北 탄도미사일 EEZ 밖 낙하…최소 500㎞ 비행”":
# ------------------------------------------------------------------
# 북    0.012262
# 한    0.016162
#      0.277005
# 지    0.008100
# 난    0.003398
#        ...
# 와    0.002880
# 다    0.002441
# 예    0.002378
# 태    0.002255
# 응    0.002404
# Length: 136, dtype: float64
#
#
# Keyword Significance Scores for "[단독]‘성희롱 논란’ 현근택 ‘3인 합의문’ 공개되자…당사자 “합의한 사실 없다”":
# ---------------------------------------------------------------------------------
# 민    0.008516
# 주    0.008500
#      0.279344
# 연    0.005947
# 구    0.006459
#        ...
# 착    0.003168
# 조    0.004474
# 온    0.003262
# 라    0.003245
# 채    0.002658
# Length: 117, dtype: float64
#
#
# Keyword Significance Scores for "‘성희롱 발언 논란’ 현근택, 피해자와 합의 중…“비난 멈춰달라”":
# -----------------------------------------------------------------------
# 변    0.002672
# 호    0.003275
# 사    0.019098
#      0.277256
# 성    0.010029
#        ...
# 명    0.004815
# 표    0.002970
# 류    0.002972
# 취    0.002946
# 방    0.002224
# Length: 116, dtype: float64
#
#
# Keyword Significance Scores for "개혁연합신당, 민주당에 ‘비례연합정당’ 제안…꼼수 위성정당 우려":
# ----------------------------------------------------------------------
# 야    0.005309
# 권    0.007901
#      0.275877
# 소    0.007698
# 수    0.004766
#        ...
# 차    0.002613
# 내    0.002319
# 향    0.002647
# 외    0.002553
# 규    0.002006
# Length: 129, dtype: float64
#
#
# Keyword Significance Scores for "당정 “취약계층 전기료 동결-소상공인 대출이자 경감”…野 “총선용 선심대책”":
# -----------------------------------------------------------------------------
# 보    0.003476
# 기    0.015325
#      0.273589
# 한    0.006454
# 덕    0.002294
#        ...
# 운    0.001707
# 데    0.001722
# 침    0.001881
# 김    0.002400
# 일    0.001633
# Length: 195, dtype: float64
#
#
# Keyword Significance Scores for "민주, 총리실 ‘1㎝ 열상’ 문자에 “테러사건 축소 왜곡”…고발 예고":
# -------------------------------------------------------------------------
# 이    0.007032
# 재    0.003131
# 명    0.006873
#      0.275283
# 더    0.003595
#        ...
# 목    0.002111
# 비    0.002196
# 채    0.002386
# 연    0.002350
# 성    0.001891
# Length: 156, dtype: float64
#
#
# ...
# 시    0.020552
#        ...
# 측    0.005121
# 근    0.005163
# 락    0.005517
# 두    0.005088
# 절    0.003759
# Length: 99, dtype: float64
#
#
# Keyword Significance Scores for "임종석, 송파갑 투입도 무산 기류…‘극 험지’ 내몰리나":
# -----------------------------------------------------------------
# 임    0.003238
# 종    0.005323
# 석    0.008925
#      0.273205
# 대    0.010939
#        ...
# 뇌    0.002512
# 내    0.002428
# 결    0.002362
# 계    0.002670
# 자    0.002172
# Length: 148, dtype: float64
#
#
# Keyword Significance Scores for "한 총리 “의료공백 최소화하겠다”…비상진료 준비상황 점검":
# ------------------------------------------------------------------
# 한    0.004276
# 덕    0.004449
# 수    0.006448
#      0.261973
# 국    0.015756
#        ...
# 복    0.003354
# 지    0.003062
# 보    0.002973
# 책    0.002843
# 반    0.002002
# Length: 116, dtype: float64
#
#
# Keyword Significance Scores for "북한, 기록영화에서도 ‘한반도 이미지’ 수정…‘두 국가’ 조치 계속":
# ------------------------------------------------------------------------
# 북    0.014667
# 한    0.021890
#      0.266196
# 기    0.011702
# 록    0.009984
#        ...
# 세    0.001996
# 어    0.001908
# 언    0.001801
# 편    0.002045
# 집    0.002121
# Length: 153, dtype: float64
#
#
# Keyword Significance Scores for "김진표 “선거구, 6개월 전 획정…안되면 선관위 안대로 획정 법에 규정해야”":
# -----------------------------------------------------------------------------
# 김    0.001464
# 진    0.004448
# 표    0.003790
#      0.280395
# 국    0.017135
#        ...
# 망    0.001820
# 야    0.001909
# 최    0.001726
# 유    0.001800
# 약    0.001734
# Length: 159, dtype: float64
#
#
# Keyword Significance Scores for "끌려나간 KAIST 졸업생 “과잉진압 사과하라”":
# -------------------------------------------------------------
# 윤    0.004562
# 석    0.009467
# 열    0.005480
#      0.264004
# 대    0.039667
#        ...
# 비    0.003749
# 피    0.003686
# 켓    0.003607
# 최    0.003756
# 재    0.003150
# Length: 115, dtype: float64
#
#
# Keyword Significance Scores for "원희룡, 이재명 겨냥 “말로만 하는 사람”…지하철 공약 발표":
# --------------------------------------------------------------------
# 실    0.005676
# 천    0.018128
#      0.272995
# 사    0.014649
# 람    0.013200
#        ...
# 청    0.004433
# 단    0.004589
# 수    0.004588
# 확    0.004479
# 성    0.003810
# Length: 96, dtype: float64
#
#
# Keyword Significance Scores for "민주당, ‘탈당 이력’ 이언주 감산 페널티 적용 않기로":
# -----------------------------------------------------------------
# 요    0.006916
# 구    0.007443
#      0.278332
# 복    0.009702
# 당    0.039456
#        ...
# 령    0.004036
# 문    0.003617
# 투    0.003753
# 발    0.003987
# 탁    0.003186
# Length: 97, dtype: float64
#
#
# Keyword Significance Scores for "민주 “윤, ‘카이스트 입틀막’ 근본 원인된 R&D 예산 문제 복원해야”":
# ---------------------------------------------------------------------------
# 과    0.010680
# 학    0.012089
#      0.266844
# 수    0.006149
# 도    0.008741
#        ...
# 녹    0.002425
# 색    0.002538
# 시    0.002212
# 변    0.002291
# 확    0.002089
# Length: 154, dtype: float64
#
#
# Keyword Significance Scores for "윤재옥 “쌍특검 재표결 44일 지나…총선용 입법”":
# --------------------------------------------------------------
# 윤    0.005166
# 재    0.012885
# 옥    0.006226
#      0.275226
# 국    0.022132
#        ...
# 다    0.004014
# 운    0.003986
# 부    0.004039
# 탁    0.004487
# 강    0.003761
# Length: 102, dtype: float64
#
#
# Keyword Significance Scores for "尹 “의료계 집단행동 대응에 만전…현안은 신속히 추진”":
# -----------------------------------------------------------------
# 윤    0.010829
# 석    0.011798
# 열    0.012983
#      0.264350
# 대    0.043288
#        ...
# 관    0.013261
# 계    0.007821
# 장    0.007821
# 재    0.007312
# 방    0.007521
# Length: 65, dtype: float64
#
#
# Keyword Significance Scores for "이준석 “이낙연, 격한 모습 통합 아냐…5개 정파 중 혼자 반대”":
# -----------------------------------------------------------------------
# 이    0.020343
# 준    0.004981
# 석    0.006219
#      0.264056
# 개    0.009969
#        ...
# 략    0.001761
# 윤    0.001921
# 열    0.001750
# 실    0.001596
# 층    0.001516
# Length: 186, dtype: float64
#
#
# Keyword Significance Scores for "조국 “6개월 복무 석사장교 미안하지만 전두환에게 따져라”":
# -------------------------------------------------------------------
# 조    0.005084
# 국    0.014350
#      0.262727
# 법    0.011890
# 무    0.013553
#        ...
# 존    0.005152
# 경    0.004837
# 심    0.005416
# 마    0.004554
# 음    0.003293
# Length: 106, dtype: float64
#
#
# Keyword Significance Scores for "이재명식 ‘내로남불’ 공천 [김지현의 정치언락]":
# -------------------------------------------------------------
# 더    0.002645
# 불    0.004055
# 어    0.002758
# 민    0.009152
# 주    0.010520
#        ...
# 책    0.001573
# 양    0.001342
# 새    0.001334
# 징    0.002515
# 머    0.001171
# Length: 228, dtype: float64
#
#
# Keyword Significance Scores for "김경율 “넷플릭스 오찬, 김 여사 활동재개했다고 봐야”":
# -----------------------------------------------------------------
# 김    0.008138
# 경    0.007809
#      0.266738
# 국    0.008108
# 민    0.006479
#        ...
# 란    0.003767
# 후    0.003149
# 잠    0.003296
# 행    0.003090
# 측    0.002037
# Length: 135, dtype: float64
#
#
# Keyword Significance Scores for "정부, 후쿠시마 오염수 누출 사고 이후 “유의미한 변화 감지 안돼”":
# ------------------------------------------------------------------------
# 구    0.007749
# 연    0.004321
#      0.269957
# 국    0.010417
# 무    0.008253
#        ...
# 용    0.003050
# 민    0.003247
# 우    0.003519
# 려    0.003633
# 최    0.002925
# Length: 127, dtype: float64
#
#
# Keyword Significance Scores for "임혁백 공관위원장, 밀실공천 논란에 “이런 일 없도록 하겠다”":
# ---------------------------------------------------------------------
# 이    0.010091
# 재    0.012797
# 명    0.006382
#      0.280103
# 밀    0.012736
#        ...
# 차    0.003045
# 례    0.003342
# 연    0.003132
# 락    0.002833
# 도    0.001863
# Length: 124, dtype: float64
#
#
# Keyword Significance Scores for "정부 “독일, 프랑스, 일본 의대증원 해도 집단행동 없었다”":
# --------------------------------------------------------------------
# 박    0.006429
# 민    0.004727
# 수    0.021827
#      0.272728
# 중    0.005142
#        ...
# 최    0.003578
# 근    0.003904
# 추    0.003639
# 강    0.003761
# 조    0.003016
# Length: 98, dtype: float64
#
#
# Keyword Significance Scores for "민주, 정책기획단 TF 발족…보육비·가상자산·직장인 관련 공약 발표":
# ------------------------------------------------------------------------
# 단    0.014421
# 장    0.014978
#      0.271909
# 명    0.013986
# 계    0.004623
#        ...
# 편    0.004897
# 격    0.004824
# 심    0.007790
# 언    0.004592
# 복    0.004517
# Length: 81, dtype: float64
#
#
# Keyword Significance Scores for "민주, 이용우·김남희·차지호 인재영입…“공동체 가치 실현”":
# -------------------------------------------------------------------
# 민    0.007956
# 주    0.008611
#      0.265714
# 인    0.018543
# 재    0.009370
#        ...
# 람    0.001260
# 식    0.001327
# 렬    0.001350
# 새    0.001382
# 벽    0.001386
# Length: 218, dtype: float64
#
#
# Keyword Significance Scores for "윤재옥, ‘카이스트 졸업생 강제퇴장’에 “정치적 의도 갖고 행사 방해”":
# --------------------------------------------------------------------------
# 강    0.008825
# 성    0.008999
# 희    0.007355
#      0.264016
# 신    0.011287
#        ...
# 라    0.003902
# 최    0.003877
# 한    0.003575
# 예    0.003218
# 금    0.002771
# Length: 117, dtype: float64
#
#
# Keyword Significance Scores for "민주당 민홍철·김정호 “낙동강벨트 선봉서 ‘김해’ 지켜낼 것”":
# ---------------------------------------------------------------------
# 더    0.004163
# 불    0.006853
# 어    0.005061
# 민    0.028621
# 주    0.009878
#        ...
# 피    0.003556
# 처    0.003535
# 만    0.002989
# 달    0.002940
# 조    0.002948
# Length: 128, dtype: float64
#
#
# Keyword Significance Scores for "개혁신당 ‘이준석 총선 지휘권’에 “전두환 국보위냐”…이낙연·김종민 퇴장":
# ---------------------------------------------------------------------------
# 이    0.022365
# 낙    0.005976
# 연    0.006215
#      0.262246
# 준    0.009824
#        ...
# 상    0.002732
# 해    0.002589
# 합    0.002639
# 소    0.003340
# 영    0.002789
# Length: 120, dtype: float64
#
#
# Keyword Significance Scores for "김해을 국힘 예비후보들 “조해진 확정되면 무소속 출마” 시사":
# --------------------------------------------------------------------
# 김    0.025392
# 해    0.026842
# 시    0.012823
#      0.282624
# 국    0.006060
#        ...
# 헌    0.004310
# 만    0.004160
# 행    0.004220
# 라    0.004233
# 고    0.004225
# Length: 100, dtype: float64
#
#
# Keyword Significance Scores for "이준석, 정책결정 위임 의결에 대해 “운영 비효율 해결…이낙연 무시 못해”":
# ----------------------------------------------------------------------------
# 권    0.006685
# 한    0.009273
#      0.267755
# 전    0.012302
# 결    0.025271
#        ...
# 생    0.005955
# 각    0.006186
# 류    0.003478
# 판    0.003609
# 단    0.002789
# Length: 121, dtype: float64
#
#
# Keyword Significance Scores for "의료계 집단행동에…軍병원 응급실 개방하고 군의관 파견 준비":
# -------------------------------------------------------------------
# 한    0.003524
# 덕    0.002762
# 수    0.011114
#      0.274378
# 국    0.017921
#        ...
# 불    0.001701
# 편    0.001761
# 소    0.001577
# 질    0.001614
# 말    0.001516
# Length: 178, dtype: float64
#
#
# Keyword Significance Scores for "여당 ‘컷오프’ 서정숙 “공천 특권 카르텔 작동…다른 당 제의 있어”":
# -------------------------------------------------------------------------
# 분    0.003193
# 과    0.007313
#      0.270334
# 인    0.012658
# 연    0.005212
#        ...
# 개    0.002752
# 혁    0.002720
# 얘    0.003351
# 중    0.003620
# 령    0.002432
# Length: 143, dtype: float64
#
#
# Keyword Significance Scores for "이준석, 이낙연 향해 “격한 모습, 통합의 모습에 맞지 않아”":
# ---------------------------------------------------------------------
# 이    0.018431
# 준    0.005334
# 석    0.005519
#      0.258230
# 개    0.010998
#        ...
# 재    0.002183
# 범    0.002342
# 죄    0.002374
# 입    0.003357
# 활    0.002069
# Length: 150, dtype: float64
#
#
# Keyword Significance Scores for "컷오프 권석창 전 의원 무소속 출마…제천·단양 5파전":
# ----------------------------------------------------------------
# 국    0.018341
# 민    0.032912
#      0.273716
# 공    0.013619
# 천    0.016231
#        ...
# 법    0.003605
# 혐    0.003252
# 죄    0.003693
# 판    0.003645
# 임    0.003355
# Length: 112, dtype: float64
#
#
# Keyword Significance Scores for "국방부 “의료 파업 시 군군수도병원 등 12개 군병원 응급실 개방”":
# ------------------------------------------------------------------------
# 민    0.010120
# 간    0.010326
#      0.270784
# 외    0.006173
# 래    0.006201
#        ...
# 공    0.003683
# 직    0.003723
# 출    0.003972
# 무    0.004306
# 중    0.003610
# Length: 105, dtype: float64
#
#
# Keyword Significance Scores for "‘공천=당선’ 민주 호남서 집안 싸움 과열…곳곳서 고소·고발전":
# ---------------------------------------------------------------------
# 이    0.007695
# 재    0.002686
# 명    0.004143
#      0.271548
# 더    0.003630
#        ...
# 티    0.002357
# 브    0.002157
# 권    0.001995
# 계    0.001902
# 배    0.001874
# Length: 158, dtype: float64
#
#
# Keyword Significance Scores for "크렘린궁 “푸틴 선물 차량은 아우루스…김정은이 좋아해”":
# -----------------------------------------------------------------
# 최    0.004510
# 초    0.003315
#      0.257594
# 고    0.010801
# 급    0.006147
#        ...
# 요    0.002507
# 속    0.002264
# 다    0.002274
# 경    0.002278
# 밀    0.002393
# Length: 143, dtype: float64
#
#
# Keyword Significance Scores for "5개 세력 ‘빅텐트’…공약부터 인선까지 사사건건 충돌":
# ----------------------------------------------------------------
# 지    0.014450
# 대    0.023981
#      0.270820
# 텐    0.001561
# 트    0.001567
#        ...
# 납    0.002206
# 강    0.001465
# 규    0.001478
# 액    0.001447
# 윤    0.001553
# Length: 189, dtype: float64
#
#
# Keyword Significance Scores for "코미디언 서승만, 민주 비례 출마 선언…“개그보다 웃긴 현실에 절박함”":
# --------------------------------------------------------------------------
# 개    0.007290
# 그    0.008210
# 맨    0.005407
#      0.264079
# 서    0.012928
#        ...
# 호    0.007857
# 변    0.005258
# 화    0.005317
# 작    0.005306
# 용    0.005257
# Length: 91, dtype: float64
#
#
# Keyword Significance Scores for "민주 공관위, ‘공천 학살’ 논란에 “공정한 경선기회 보장”…뒤늦게 진화":
# ---------------------------------------------------------------------------
# 내    0.006461
# 일    0.004461
#      0.285597
# 서    0.006740
# 울    0.006670
#        ...
# 임    0.003950
# 혁    0.003783
# 백    0.003775
# 속    0.004928
# 청    0.003173
# Length: 115, dtype: float64
#
#
# Keyword Significance Scores for "대통령실 “의대, 3천명 필요하지만 2천명 결정…지금 안하면 더 늘려야”":
# ---------------------------------------------------------------------------
# 성    0.004928
# 태    0.005253
#      0.280964
# 정    0.027034
# 책    0.011698
#        ...
# 완    0.004015
# 화    0.003749
# 역    0.003374
# 합    0.003744
# 거    0.003691
# Length: 114, dtype: float64
#
#
# Keyword Significance Scores for "민주, 논란의 하위 20% 명단에 “누군지 모른다”":
# ---------------------------------------------------------------
# 김    0.004641
# 병    0.005109
# 기    0.011500
#      0.276426
# 중    0.009292
#        ...
# 양    0.005540
# 상    0.005556
# 동    0.003468
# 생    0.003609
# 각    0.003664
# Length: 105, dtype: float64
#
#
# Keyword Significance Scores for "尹 축사 중 소리친 카이스트 졸업식 소동, 사전 예고됐다":
# ------------------------------------------------------------------
# 윤    0.005006
# 석    0.010148
# 열    0.005997
#      0.259892
# 대    0.043061
#        ...
# 규    0.003769
# 칙    0.003709
# 김    0.005855
# 혜    0.005025
# 린    0.004169
# Length: 100, dtype: float64
#
#
# Keyword Significance Scores for "민주당 하위 20%, 비명 대거 포함…비명계 “이재명의 공천 학살” 반발":
# ---------------------------------------------------------------------------
# 이    0.013534
# 재    0.008093
# 명    0.017209
#      0.268091
# 더    0.004829
#        ...
# 환    0.002535
# 골    0.002753
# 태    0.002629
# 다    0.002243
# 채    0.002092
# Length: 154, dtype: float64
#
#
# Keyword Significance Scores for "민주당 텃밭 광진 찾아 오신환 손 들어올린 한동훈 [총선 LIVE]":
# ------------------------------------------------------------------------
# 국    0.010577
# 민    0.025616
#      0.270025
# 한    0.005079
# 동    0.013077
#        ...
# 피    0.001816
# 등    0.001695
# 록    0.001707
# 체    0.001578
# 우    0.001339
# Length: 183, dtype: float64
#
#
# Keyword Significance Scores for "尹, 저출산고령사회위원회 부위원장 부총리급 격상하고 상근직 전환":
# ----------------------------------------------------------------------
# 윤    0.003190
# 석    0.004914
# 열    0.003739
#      0.268319
# 대    0.024970
#        ...
# 권    0.002214
# 치    0.002401
# 개    0.002605
# 입    0.002468
# 헌    0.001629
# Length: 150, dtype: float64
#
#
# Keyword Significance Scores for "尹 “민생 현안에 독일 방문 연기”…獨 대통령 “충분히 이해”":
# ---------------------------------------------------------------------
# 윤    0.003859
# 석    0.004708
# 열    0.005400
#      0.278504
# 대    0.021439
#        ...
# 흘    0.003832
# 격    0.003557
# 김    0.005476
# 혜    0.004734
# 린    0.003882
# Length: 109, dtype: float64
#
#
# Keyword Significance Scores for "‘무면허 의료사망’ 권대희 사건 前검사, 대통령 공직기강실 근무 논란":
# -------------------------------------------------------------------------
# 용    0.003468
# 산    0.002272
#      0.275142
# 대    0.012502
# 통    0.006402
#        ...
# 개    0.002477
# 잘    0.004214
# 못    0.004060
# 석    0.002614
# 적    0.002590
# Length: 133, dtype: float64
#
#
# Keyword Significance Scores for "윤, 김현숙 여가장관 사표 곧 수리…차관 대행 체제 운영":
# ------------------------------------------------------------------
# 후    0.025035
# 임    0.025555
#      0.269532
# 명    0.019671
# 윤    0.007009
#        ...
# 감    0.006802
# 출    0.006585
# 분    0.006394
# 직    0.006591
# 실    0.006511
# Length: 68, dtype: float64
#
#
# Keyword Significance Scores for "이재명 “내가 점수 줬다면 김영주 분명 좋은 평가…안타까워”":
# --------------------------------------------------------------------
# 이    0.021792
# 재    0.012386
# 명    0.013325
#      0.275202
# 더    0.006217
#        ...
# 한    0.004171
# 편    0.004038
# 망    0.003660
# 고    0.004013
# 도    0.003164
# Length: 102, dtype: float64
#
#
# Keyword Significance Scores for "정부 재정 지원 약발 안 통했다…사립대 17% 등록금 인상":
# -------------------------------------------------------------------
# 제    0.003726
# 국    0.016416
#      0.265027
# 한    0.010853
# 대    0.031085
#        ...
# 적    0.002785
# 현    0.003088
# 실    0.003121
# 촉    0.003015
# 획    0.002321
# Length: 100, dtype: float64
#
#
# Keyword Significance Scores for "“강제 북송 중단하라”…탈북다큐 출연진, 주영 北대사관서 시위":
# ---------------------------------------------------------------------
# 사    0.019241
# 진    0.007687
#      0.262335
# 김    0.008901
# 성    0.006142
#        ...
# 객    0.003551
# 수    0.003801
# 불    0.003822
# 기    0.003742
# 욱    0.002983
# Length: 112, dtype: float64
#
#
# Keyword Significance Scores for "이재명 습격범 “자포자기 심정 아닌 순수한 정치적 명분 따라 행동”":
# ------------------------------------------------------------------------
# 이    0.011724
# 재    0.011805
# 명    0.009519
#      0.276542
# 더    0.003724
#        ...
# 다    0.001918
# 음    0.001917
# 종    0.002016
# 합    0.002059
# 예    0.001717
# Length: 170, dtype: float64
#
#
# Keyword Significance Scores for "헌정 첫 검사 탄핵심판 시작…“공소권 남용” vs “원칙 처분”":
# ----------------------------------------------------------------------
# 청    0.010410
# 구    0.009711
#      0.281093
# 검    0.015196
# 찰    0.006254
#        ...
# 발    0.001787
# 견    0.001778
# 존    0.001189
# 논    0.001371
# 란    0.001390
# Length: 196, dtype: float64
#
#
# Keyword Significance Scores for "“10번 중 7번 꼴로 지각해도 재외공관 인사평가 최상위”":
# -------------------------------------------------------------------
# 서    0.003510
# 울    0.002687
#      0.278433
# 종    0.003356
# 로    0.006813
#        ...
# 법    0.002584
# 례    0.002432
# 선    0.002804
# 통    0.002715
# 규    0.001987
# Length: 130, dtype: float64
