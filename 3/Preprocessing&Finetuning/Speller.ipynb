# %%
pip install autocorrect
# Out:
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.8/622.8 kB 17.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622363 sha256=2da9dfaa28b04892c5ef5f1aa52e51a345a937ecdee2230eb0e25e910e8ef6fe
#   Stored in directory: /root/.cache/pip/wheels/b5/7b/6d/b76b29ce11ff8e2521c8c7dd0e5bfee4fb1789d76193124343
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1

# %%
from autocorrect import Speller

spell = Speller("en")

# %%
spell("holding written fade ext neighborhood street morning twin boys rudy jacob carges ride bikes suburban neighborhoo")
# Out:
# 'holding written fade ext neighborhood street morning twin boys rude jacob charges ride bikes suburban neighborhood'

# %% [markdown]
# # token별로 안하고 문장 전체로 스펠링 검사하기 + 중복단어 지우기?(뉘앙스 보존위해 냅두기 일단)

# %%
import pandas as pd
import re
from autocorrect import Speller

# Initialize the Speller from autocorrect
spell = Speller("en")

i = 1

# Function to preprocess text using regex, spaCy for NER, and autocorrect for spelling correction
def preprocess_text(text):
    global i

    # Correct spelling mistakes
    final_cleaned_text = spell(text)

    print(f"{i}번째 완료")
    i += 1
    return final_cleaned_text

# Load CSV file
output_csv_path = "/content/scripts_speller.csv"
input_csv_path = "/content/scripts_preprocessed.csv"
df = pd.read_csv(input_csv_path)

df = df.dropna()

# Preprocess the movie scripts in the second column
df['script'] = df.iloc[:, 1].apply(preprocess_text)

# Save the preprocessed scripts to a new CSV file
df.to_csv(output_csv_path, index=False)

print("Preprocessing complete. Cleaned scripts saved to:", output_csv_path)
# Out:
# 1번째 완료
# 2번째 완료
# 3번째 완료
# 4번째 완료
# 5번째 완료
# 6번째 완료
# 7번째 완료
# 8번째 완료
# 9번째 완료
# 10번째 완료
# 11번째 완료
# 12번째 완료
# 13번째 완료
# 14번째 완료
# 15번째 완료
# 16번째 완료
# 17번째 완료
# 18번째 완료
# 19번째 완료
# 20번째 완료
# 21번째 완료
# 22번째 완료
# 23번째 완료
# 24번째 완료
# 25번째 완료
# 26번째 완료
# 27번째 완료
# 28번째 완료
# 29번째 완료
# 30번째 완료
# 31번째 완료
# 32번째 완료
# 33번째 완료
# 34번째 완료
# 35번째 완료
# 36번째 완료
# 37번째 완료
# 38번째 완료
# 39번째 완료
# 40번째 완료
# 41번째 완료
# 42번째 완료
# 43번째 완료
# 44번째 완료
# 45번째 완료
# 46번째 완료
# 47번째 완료
# 48번째 완료
# 49번째 완료
# 50번째 완료
# 51번째 완료
# 52번째 완료
# 53번째 완료
# 54번째 완료
# 55번째 완료
# 56번째 완료
# 57번째 완료
# 58번째 완료
# 59번째 완료
# 60번째 완료
# 61번째 완료
# 62번째 완료
# 63번째 완료
# 64번째 완료
# 65번째 완료
# 66번째 완료
# 67번째 완료
# 68번째 완료
# 69번째 완료
# 70번째 완료
# 71번째 완료
# 72번째 완료
# 73번째 완료
# 74번째 완료
# 75번째 완료
# 76번째 완료
# 77번째 완료
# 78번째 완료
# 79번째 완료
# 80번째 완료
# 81번째 완료
# 82번째 완료
# 83번째 완료
# 84번째 완료
# 85번째 완료
# 86번째 완료
# 87번째 완료
# 88번째 완료
# 89번째 완료
# 90번째 완료
# 91번째 완료
# 92번째 완료
# 93번째 완료
# 94번째 완료
# 95번째 완료
# 96번째 완료
# 97번째 완료
# 98번째 완료
# 99번째 완료
# 100번째 완료
# 101번째 완료
# 102번째 완료
# 103번째 완료
# 104번째 완료
# 105번째 완료
# 106번째 완료
# 107번째 완료
# 108번째 완료
# 109번째 완료
# 110번째 완료
# 111번째 완료
# 112번째 완료
# 113번째 완료
# 114번째 완료
# 115번째 완료
# 116번째 완료
# 117번째 완료
# 118번째 완료
# 119번째 완료
# 120번째 완료
# 121번째 완료
# 122번째 완료
# 123번째 완료
# 124번째 완료
# 125번째 완료
# 126번째 완료
# 127번째 완료
# 128번째 완료
# 129번째 완료
# 130번째 완료
# 131번째 완료
# 132번째 완료
# 133번째 완료
# 134번째 완료
# 135번째 완료
# 136번째 완료
# 137번째 완료
# 138번째 완료
# 139번째 완료
# 140번째 완료
# 141번째 완료
# 142번째 완료
# 143번째 완료
# 144번째 완료
# 145번째 완료
# 146번째 완료
# 147번째 완료
# 148번째 완료
# 149번째 완료
# 150번째 완료
# 151번째 완료
# 152번째 완료
# 153번째 완료
# 154번째 완료
# 155번째 완료
# 156번째 완료
# 157번째 완료
# 158번째 완료
# 159번째 완료
# 160번째 완료
# 161번째 완료
# 162번째 완료
# 163번째 완료
# 164번째 완료
# 165번째 완료
# 166번째 완료
# 167번째 완료
# 168번째 완료
# 169번째 완료
# 170번째 완료
# 171번째 완료
# 172번째 완료
# 173번째 완료
# 174번째 완료
# 175번째 완료
# 176번째 완료
# 177번째 완료
# 178번째 완료
# 179번째 완료
# 180번째 완료
# 181번째 완료
# 182번째 완료
# 183번째 완료
# 184번째 완료
# 185번째 완료
# 186번째 완료
# 187번째 완료
# 188번째 완료
# 189번째 완료
# 190번째 완료
# 191번째 완료
# 192번째 완료
# 193번째 완료
# 194번째 완료
# 195번째 완료
# 196번째 완료
# 197번째 완료
# 198번째 완료
# 199번째 완료
# 200번째 완료
# 201번째 완료
# 202번째 완료
# 203번째 완료
# 204번째 완료
# 205번째 완료
# 206번째 완료
# 207번째 완료
# 208번째 완료
# 209번째 완료
# 210번째 완료
# 211번째 완료
# 212번째 완료
# 213번째 완료
# 214번째 완료
# 215번째 완료
# 216번째 완료
# 217번째 완료
# 218번째 완료
# 219번째 완료
# 220번째 완료
# 221번째 완료
# 222번째 완료
# 223번째 완료
# 224번째 완료
# 225번째 완료
# 226번째 완료
# 227번째 완료
# 228번째 완료
# 229번째 완료
# 230번째 완료
# 231번째 완료
# 232번째 완료
# 233번째 완료
# 234번째 완료
# 235번째 완료
# 236번째 완료
# 237번째 완료
# 238번째 완료
# 239번째 완료
# 240번째 완료
# 241번째 완료
# 242번째 완료
# 243번째 완료
# 244번째 완료
# 245번째 완료
# 246번째 완료
# 247번째 완료
# 248번째 완료
# 249번째 완료
# 250번째 완료
# 251번째 완료
# 252번째 완료
# 253번째 완료
# 254번째 완료
# 255번째 완료
# 256번째 완료
# 257번째 완료
# 258번째 완료
# 259번째 완료
# 260번째 완료
# 261번째 완료
# 262번째 완료
# 263번째 완료
# 264번째 완료
# 265번째 완료
# 266번째 완료
# 267번째 완료
# 268번째 완료
# 269번째 완료
# 270번째 완료
# 271번째 완료
# 272번째 완료
# 273번째 완료
# 274번째 완료
# 275번째 완료
# 276번째 완료
# 277번째 완료
# 278번째 완료
# 279번째 완료
# 280번째 완료
# 281번째 완료
# 282번째 완료
# 283번째 완료
# 284번째 완료
# 285번째 완료
# 286번째 완료
# 287번째 완료
# 288번째 완료
# 289번째 완료
# 290번째 완료
# 291번째 완료
# 292번째 완료
# 293번째 완료
# 294번째 완료
# 295번째 완료
# 296번째 완료
# 297번째 완료
# 298번째 완료
# 299번째 완료
# 300번째 완료
# 301번째 완료
# 302번째 완료
# 303번째 완료
# 304번째 완료
# 305번째 완료
# 306번째 완료
# 307번째 완료
# 308번째 완료
# 309번째 완료
# 310번째 완료
# 311번째 완료
# 312번째 완료
# 313번째 완료
# 314번째 완료
# 315번째 완료
# 316번째 완료
# 317번째 완료
# 318번째 완료
# 319번째 완료
# 320번째 완료
# 321번째 완료
# 322번째 완료
# 323번째 완료
# 324번째 완료
# 325번째 완료
# 326번째 완료
# 327번째 완료
# 328번째 완료
# 329번째 완료
# 330번째 완료
# 331번째 완료
# 332번째 완료
# 333번째 완료
# 334번째 완료
# 335번째 완료
# 336번째 완료
# 337번째 완료
# 338번째 완료
# 339번째 완료
# 340번째 완료
# 341번째 완료
# 342번째 완료
# 343번째 완료
# 344번째 완료
# 345번째 완료
# 346번째 완료
# 347번째 완료
# 348번째 완료
# 349번째 완료
# 350번째 완료
# 351번째 완료
# 352번째 완료
# 353번째 완료
# 354번째 완료
# 355번째 완료
# 356번째 완료
# 357번째 완료
# 358번째 완료
# 359번째 완료
# 360번째 완료
# 361번째 완료
# 362번째 완료
# 363번째 완료
# 364번째 완료
# 365번째 완료
# 366번째 완료
# 367번째 완료
# 368번째 완료
# 369번째 완료
# 370번째 완료
# 371번째 완료
# 372번째 완료
# 373번째 완료
# 374번째 완료
# 375번째 완료
# 376번째 완료
# 377번째 완료
# 378번째 완료
# 379번째 완료
# 380번째 완료
# 381번째 완료
# 382번째 완료
# 383번째 완료
# 384번째 완료
# 385번째 완료
# 386번째 완료
# 387번째 완료
# 388번째 완료
# 389번째 완료
# 390번째 완료
# 391번째 완료
# 392번째 완료
# 393번째 완료
# 394번째 완료
# 395번째 완료
# 396번째 완료
# 397번째 완료
# 398번째 완료
# 399번째 완료
# 400번째 완료
# 401번째 완료
# 402번째 완료
# 403번째 완료
